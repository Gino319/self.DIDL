# %%
import torch
import torch.nn as nn

net = nn.Sequential(nn.Linear(4, 8), nn.ReLU(), nn.Linear(8, 1))

X = torch.rand(size=[2, 4])
print(net(X))
# Out:
# tensor([[0.2839],
#         [0.4507]], grad_fn=<AddmmBackward0>)

# %%
# 参数访问
print(net[2].state_dict())
print(type(net[2].bias))
print(net[2].bias)
print(net[2].bias.data)
# Out:
# OrderedDict([('weight', tensor([[ 0.2886,  0.0419,  0.1251,  0.2836,  0.2142, -0.0825,  0.0351, -0.3389]])), ('bias', tensor([0.0422]))])
# <class 'torch.nn.parameter.Parameter'>
# Parameter containing:
# tensor([0.0422], requires_grad=True)
# tensor([0.0422])

# %%
print(*[(name, param.shape) for name, param in net[2].named_parameters()])
print(*[(name, param.shape) for name, param in net.named_parameters()])
# Out:
# ('weight', torch.Size([1, 8])) ('bias', torch.Size([1]))
# ('0.weight', torch.Size([8, 4])) ('0.bias', torch.Size([8])) ('2.weight', torch.Size([1, 8])) ('2.bias', torch.Size([1]))

# %%
print(net.state_dict()['2.bias'].data)
# Out:
# tensor([0.0422])

# %%
# 从嵌套块收集参数
def block1():
    return nn.Sequential(nn.Linear(4, 8), nn.ReLU(), nn.Linear(8, 4), nn.ReLU())

def block2():
    net = nn.Sequential()
    for i in range(4):
#         net._modules[f'block {i}'] = block1()
        net.add_module(f'block {i}', block1())
    
    return net
        
net = nn.Sequential(block2(), nn.Linear(4, 1))
print(net)
# Out:
# Sequential(
#   (0): Sequential(
#     (block 0): Sequential(
#       (0): Linear(in_features=4, out_features=8, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=8, out_features=4, bias=True)
#       (3): ReLU()
#     )
#     (block 1): Sequential(
#       (0): Linear(in_features=4, out_features=8, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=8, out_features=4, bias=True)
#       (3): ReLU()
#     )
#     (block 2): Sequential(
#       (0): Linear(in_features=4, out_features=8, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=8, out_features=4, bias=True)
#       (3): ReLU()
#     )
#     (block 3): Sequential(
#       (0): Linear(in_features=4, out_features=8, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=8, out_features=4, bias=True)
#       (3): ReLU()
#     )
#   )
#   (1): Linear(in_features=4, out_features=1, bias=True)
# )

# %%
print(net[0][1][0].bias.data)
# Out:
# tensor([ 0.4291, -0.3281,  0.2791, -0.2385, -0.0843,  0.4811, -0.0657, -0.2932])

# %%
# 参数绑定
shared = nn.Linear(8, 8)
nn.init.constant_(shared.weight, 0.1)
nn.init.constant_(shared.bias, 0)

net = nn.Sequential(nn.Linear(4, 8),
                    shared,
                    shared,
                    nn.Linear(8, 1))

n_train = 100
true_w = torch.tensor([0.1 * i for i in range(1, 5)])
features = torch.normal(size=(n_train, 4), mean=0, std=0.01)
labels = torch.mm(features, true_w.view(-1, 1))

batch_size = 10
train_data = torch.utils.data.TensorDataset(features, labels)
train_iter = torch.utils.data.DataLoader(train_data, batch_size=batch_size)

loss = nn.MSELoss()
optimizer = torch.optim.SGD(net.parameters(), lr=0.01)

n_epochs = 10
for epoch in range(n_epochs):
    for X, y in train_iter:
        optimizer.zero_grad()
        y_hat = net(X)
        l = loss(y_hat, y.view(y_hat.shape))
        l.backward()
        optimizer.step()
    
    print(f'epoch {epoch}：')
    for name, param in net.named_parameters():
        print(name, 'data:', param.data)
        print(name, 'grad:', param.grad)
# Out:
# epoch 0：
# 0.weight data: tensor([[-0.3811, -0.0793,  0.2477, -0.4919],
#         [-0.4294, -0.0051,  0.0947, -0.1152],
#         [-0.2401, -0.0871, -0.3302,  0.1950],
#         [-0.4377, -0.4623, -0.1647,  0.1332],
#         [-0.1423,  0.0505, -0.1142, -0.2791],
#         [-0.4233, -0.2119,  0.4646,  0.3153],
#         [ 0.0065, -0.1471,  0.0376,  0.1088],
#         [-0.1480, -0.3733, -0.2106, -0.3045]])
# 0.weight grad: tensor([[-9.7476e-05, -5.8327e-05,  5.2640e-05,  1.0381e-05],
#         [-9.6206e-05, -5.7567e-05,  5.1954e-05,  1.0246e-05],
#         [-9.6702e-05, -5.7864e-05,  5.2221e-05,  1.0298e-05],
#         [-9.6558e-05, -5.7778e-05,  5.2144e-05,  1.0283e-05],
#         [-9.5922e-05, -5.7398e-05,  5.1800e-05,  1.0215e-05],
#         [-9.6056e-05, -5.7477e-05,  5.1873e-05,  1.0230e-05],
#         [-9.6103e-05, -5.7505e-05,  5.1898e-05,  1.0235e-05],
#         [-9.6042e-05, -5.7469e-05,  5.1865e-05,  1.0228e-05]])
# 0.bias data: tensor([ 0.4666, -0.1522,  0.0950,  0.0188, -0.2894, -0.2218, -0.2006, -0.2326])
# 0.bias grad: tensor([-0.0166, -0.0164, -0.0165, -0.0165, -0.0163, -0.0164, -0.0164, -0.0164])
# 1.weight data: tensor([[0.1014, 0.0999, 0.1005, 0.1003, 0.0996, 0.0997, 0.0998, 0.0997],
#         [0.1007, 0.0993, 0.0999, 0.0997, 0.0990, 0.0991, 0.0992, 0.0991],
#         [0.1015, 0.1000, 0.1007, 0.1004, 0.0997, 0.0999, 0.0999, 0.0998],
#         [0.1008, 0.0994, 0.0999, 0.0998, 0.0991, 0.0992, 0.0993, 0.0992],
#         [0.1007, 0.0993, 0.0998, 0.0997, 0.0990, 0.0991, 0.0992, 0.0991],
#         [0.1010, 0.0995, 0.1001, 0.0999, 0.0992, 0.0994, 0.0994, 0.0993],
#         [0.1008, 0.0994, 0.0999, 0.0998, 0.0991, 0.0992, 0.0993, 0.0992],
#         [0.1006, 0.0992, 0.0997, 0.0996, 0.0989, 0.0990, 0.0990, 0.0990]])
# 1.weight grad: tensor([[-1.2381e-02,  1.0507e-03, -4.8164e-03, -2.5512e-03,  3.8993e-03,
#           2.3400e-03,  1.9517e-03,  2.8423e-03],
#         [-6.2479e-03,  5.7901e-03,  1.4841e-03,  2.3721e-03,  8.4949e-03,
#           7.5072e-03,  6.8147e-03,  7.2339e-03],
#         [-1.3578e-02,  1.1743e-05, -6.1305e-03, -3.5911e-03,  2.8608e-03,
#           1.1944e-03,  8.7630e-04,  1.8594e-03],
#         [-6.9652e-03,  5.2587e-03,  7.6438e-04,  1.8123e-03,  7.9859e-03,
#           6.9305e-03,  6.2714e-03,  6.7456e-03],
#         [-5.6885e-03,  6.2035e-03,  2.0448e-03,  2.8080e-03,  8.8907e-03,
#           7.9558e-03,  7.2373e-03,  7.6137e-03],
#         [-8.4029e-03,  4.0580e-03, -7.7934e-04,  5.9576e-04,  6.7973e-03,
#           5.6113e-03,  5.0320e-03,  5.6172e-03],
#         [-6.8962e-03,  5.2625e-03,  7.9841e-04,  1.8332e-03,  7.9762e-03,
#           6.9291e-03,  6.2712e-03,  6.7404e-03],
#         [-4.6389e-03,  7.0524e-03,  3.1511e-03,  3.6769e-03,  9.7241e-03,
#           8.8856e-03,  8.1115e-03,  8.4069e-03]])
# 1.bias data: tensor([-0.0032,  0.0090, -0.0058,  0.0076,  0.0101,  0.0046,  0.0077,  0.0123])
# 1.bias grad: tensor([ 0.0286, -0.0796,  0.0518, -0.0674, -0.0891, -0.0404, -0.0677, -0.1083])
# 3.weight data: tensor([[-0.1371,  0.1637, -0.2009,  0.1295,  0.1903,  0.0550,  0.1307,  0.2434]])
# 3.weight grad: tensor([[0.0148, 0.0107, 0.0156, 0.0112, 0.0103, 0.0122, 0.0111, 0.0096]])
# 3.bias data: tensor([-0.1644])
# 3.bias grad: tensor([-0.3607])
# epoch 1：
# 0.weight data: tensor([[-0.3811, -0.0793,  0.2477, -0.4919],
#         [-0.4294, -0.0051,  0.0947, -0.1152],
#         [-0.2401, -0.0871, -0.3302,  0.1950],
#         [-0.4377, -0.4623, -0.1647,  0.1332],
#         [-0.1423,  0.0505, -0.1142, -0.2791],
#         [-0.4233, -0.2119,  0.4646,  0.3153],
#         [ 0.0065, -0.1471,  0.0376,  0.1088],
#         [-0.1480, -0.3733, -0.2106, -0.3045]])
# 0.weight grad: tensor([[-7.3994e-05, -4.4444e-05,  3.9271e-05,  7.0959e-06],
#         [-7.2253e-05, -4.3398e-05,  3.8347e-05,  6.9289e-06],
#         [-7.2919e-05, -4.3798e-05,  3.8700e-05,  6.9928e-06],
#         [-7.2739e-05, -4.3690e-05,  3.8605e-05,  6.9755e-06],
#         [-7.1862e-05, -4.3163e-05,  3.8139e-05,  6.8914e-06],
#         [-7.2038e-05, -4.3269e-05,  3.8233e-05,  6.9083e-06],
#         [-7.2108e-05, -4.3311e-05,  3.8270e-05,  6.9151e-06],
#         [-7.2031e-05, -4.3265e-05,  3.8229e-05,  6.9077e-06]])
# 0.bias data: tensor([ 0.4680, -0.1508,  0.0964,  0.0202, -0.2880, -0.2204, -0.1992, -0.2312])
# 0.bias grad: tensor([-0.0125, -0.0122, -0.0123, -0.0123, -0.0122, -0.0122, -0.0122, -0.0122])
# 1.weight data: tensor([[0.1025, 0.0998, 0.1009, 0.1005, 0.0992, 0.0995, 0.0996, 0.0994],
#         [0.1013, 0.0989, 0.0997, 0.0996, 0.0983, 0.0985, 0.0987, 0.0986],
#         [0.1027, 0.1000, 0.1012, 0.1007, 0.0994, 0.0998, 0.0998, 0.0996],
#         [0.1014, 0.0990, 0.0999, 0.0997, 0.0984, 0.0987, 0.0988, 0.0987],
#         [0.1012, 0.0988, 0.0996, 0.0995, 0.0982, 0.0985, 0.0986, 0.0985],
#         [0.1017, 0.0992, 0.1002, 0.0999, 0.0987, 0.0989, 0.0990, 0.0989],
#         [0.1014, 0.0990, 0.0999, 0.0997, 0.0984, 0.0987, 0.0988, 0.0987],
#         [0.1010, 0.0986, 0.0994, 0.0993, 0.0981, 0.0983, 0.0984, 0.0983]])
# 1.weight grad: tensor([[-0.0094,  0.0011, -0.0038, -0.0017,  0.0033,  0.0019,  0.0017,  0.0025],
#         [-0.0046,  0.0039,  0.0012,  0.0014,  0.0059,  0.0054,  0.0047,  0.0049],
#         [-0.0103,  0.0004, -0.0048, -0.0023,  0.0026,  0.0011,  0.0010,  0.0020],
#         [-0.0052,  0.0036,  0.0007,  0.0011,  0.0056,  0.0050,  0.0044,  0.0046],
#         [-0.0042,  0.0042,  0.0017,  0.0017,  0.0061,  0.0057,  0.0050,  0.0051],
#         [-0.0063,  0.0029, -0.0006,  0.0003,  0.0049,  0.0041,  0.0036,  0.0040],
#         [-0.0051,  0.0036,  0.0007,  0.0011,  0.0056,  0.0050,  0.0044,  0.0046],
#         [-0.0034,  0.0047,  0.0026,  0.0023,  0.0066,  0.0063,  0.0056,  0.0055]])
# 1.bias data: tensor([-0.0057,  0.0158, -0.0102,  0.0134,  0.0177,  0.0080,  0.0135,  0.0215])
# 1.bias grad: tensor([ 0.0223, -0.0602,  0.0401, -0.0509, -0.0675, -0.0302, -0.0511, -0.0822])
# 3.weight data: tensor([[-0.1383,  0.1630, -0.2022,  0.1288,  0.1896,  0.0542,  0.1300,  0.2429]])
# 3.weight grad: tensor([[0.0107, 0.0049, 0.0119, 0.0055, 0.0044, 0.0070, 0.0055, 0.0034]])
# 3.bias data: tensor([-0.1335])
# 3.bias grad: tensor([-0.2751])
# epoch 2：
# 0.weight data: tensor([[-0.3811, -0.0793,  0.2477, -0.4919],
#         [-0.4294, -0.0051,  0.0947, -0.1152],
#         [-0.2401, -0.0871, -0.3302,  0.1950],
#         [-0.4377, -0.4623, -0.1647,  0.1332],
#         [-0.1423,  0.0505, -0.1142, -0.2791],
#         [-0.4233, -0.2119,  0.4646,  0.3153],
#         [ 0.0065, -0.1471,  0.0376,  0.1088],
#         [-0.1480, -0.3733, -0.2106, -0.3045]])
# 0.weight grad: tensor([[-5.6730e-05, -3.4238e-05,  2.9432e-05,  4.6703e-06],
#         [-5.4961e-05, -3.3170e-05,  2.8515e-05,  4.5247e-06],
#         [-5.5627e-05, -3.3572e-05,  2.8860e-05,  4.5795e-06],
#         [-5.5457e-05, -3.3470e-05,  2.8772e-05,  4.5655e-06],
#         [-5.4563e-05, -3.2930e-05,  2.8308e-05,  4.4919e-06],
#         [-5.4737e-05, -3.3035e-05,  2.8398e-05,  4.5062e-06],
#         [-5.4812e-05, -3.3081e-05,  2.8437e-05,  4.5124e-06],
#         [-5.4738e-05, -3.3036e-05,  2.8399e-05,  4.5063e-06]])
# 0.bias data: tensor([ 0.4690, -0.1498,  0.0975,  0.0213, -0.2869, -0.2194, -0.1981, -0.2302])
# 0.bias grad: tensor([-0.0095, -0.0092, -0.0093, -0.0093, -0.0092, -0.0092, -0.0092, -0.0092])
# 1.weight data: tensor([[0.1033, 0.0997, 0.1013, 0.1006, 0.0989, 0.0994, 0.0994, 0.0992],
#         [0.1017, 0.0986, 0.0996, 0.0995, 0.0978, 0.0981, 0.0983, 0.0982],
#         [0.1036, 0.0999, 0.1016, 0.1009, 0.0992, 0.0997, 0.0997, 0.0994],
#         [0.1019, 0.0987, 0.0998, 0.0996, 0.0980, 0.0982, 0.0984, 0.0983],
#         [0.1015, 0.0985, 0.0995, 0.0994, 0.0977, 0.0980, 0.0982, 0.0981],
#         [0.1022, 0.0990, 0.1002, 0.0999, 0.0982, 0.0986, 0.0987, 0.0986],
#         [0.1018, 0.0987, 0.0998, 0.0996, 0.0980, 0.0982, 0.0984, 0.0983],
#         [0.1013, 0.0983, 0.0992, 0.0991, 0.0976, 0.0978, 0.0980, 0.0979]])
# 1.weight grad: tensor([[-0.0072,  0.0010, -0.0030, -0.0011,  0.0027,  0.0016,  0.0015,  0.0022],
#         [-0.0035,  0.0027,  0.0010,  0.0009,  0.0042,  0.0039,  0.0034,  0.0034],
#         [-0.0079,  0.0006, -0.0038, -0.0015,  0.0023,  0.0010,  0.0010,  0.0018],
#         [-0.0039,  0.0026,  0.0006,  0.0006,  0.0041,  0.0037,  0.0032,  0.0033],
#         [-0.0031,  0.0029,  0.0014,  0.0011,  0.0043,  0.0041,  0.0035,  0.0035],
#         [-0.0047,  0.0021, -0.0004,  0.0002,  0.0036,  0.0030,  0.0027,  0.0029],
#         [-0.0039,  0.0025,  0.0006,  0.0007,  0.0040,  0.0036,  0.0032,  0.0032],
#         [-0.0025,  0.0032,  0.0021,  0.0014,  0.0046,  0.0046,  0.0039,  0.0037]])
# 1.bias data: tensor([-0.0076,  0.0210, -0.0137,  0.0177,  0.0235,  0.0106,  0.0178,  0.0285])
# 1.bias grad: tensor([ 0.0173, -0.0458,  0.0310, -0.0387, -0.0514, -0.0228, -0.0388, -0.0626])
# 3.weight data: tensor([[-0.1392,  0.1627, -0.2031,  0.1284,  0.1894,  0.0537,  0.1296,  0.2428]])
# 3.weight grad: tensor([[0.0078, 0.0019, 0.0091, 0.0025, 0.0013, 0.0040, 0.0025, 0.0003]])
# 3.bias data: tensor([-0.1100])
# 3.bias grad: tensor([-0.2103])
# epoch 3：
# 0.weight data: tensor([[-0.3811, -0.0793,  0.2477, -0.4919],
#         [-0.4294, -0.0051,  0.0947, -0.1152],
#         [-0.2401, -0.0871, -0.3302,  0.1950],
#         [-0.4377, -0.4623, -0.1647,  0.1332],
#         [-0.1423,  0.0505, -0.1142, -0.2791],
#         [-0.4233, -0.2119,  0.4646,  0.3153],
#         [ 0.0065, -0.1471,  0.0376,  0.1088],
#         [-0.1480, -0.3733, -0.2106, -0.3045]])
# 0.weight grad: tensor([[-4.3814e-05, -2.6604e-05,  2.2066e-05,  2.8493e-06],
#         [-4.2200e-05, -2.5624e-05,  2.1253e-05,  2.7444e-06],
#         [-4.2800e-05, -2.5988e-05,  2.1555e-05,  2.7834e-06],
#         [-4.2655e-05, -2.5900e-05,  2.1482e-05,  2.7739e-06],
#         [-4.1836e-05, -2.5403e-05,  2.1070e-05,  2.7207e-06],
#         [-4.1991e-05, -2.5497e-05,  2.1148e-05,  2.7308e-06],
#         [-4.2063e-05, -2.5541e-05,  2.1184e-05,  2.7355e-06],
#         [-4.1999e-05, -2.5502e-05,  2.1152e-05,  2.7313e-06]])
# 0.bias data: tensor([ 0.4699, -0.1490,  0.0983,  0.0221, -0.2862, -0.2186, -0.1974, -0.2294])
# 0.bias grad: tensor([-0.0073, -0.0070, -0.0071, -0.0071, -0.0069, -0.0070, -0.0070, -0.0070])
# 1.weight data: tensor([[0.1039, 0.0996, 0.1015, 0.1007, 0.0987, 0.0992, 0.0993, 0.0990],
#         [0.1020, 0.0983, 0.0995, 0.0994, 0.0975, 0.0978, 0.0980, 0.0979],
#         [0.1042, 0.0999, 0.1019, 0.1010, 0.0990, 0.0996, 0.0996, 0.0993],
#         [0.1022, 0.0985, 0.0998, 0.0996, 0.0976, 0.0979, 0.0981, 0.0980],
#         [0.1018, 0.0982, 0.0994, 0.0993, 0.0974, 0.0977, 0.0979, 0.0978],
#         [0.1026, 0.0988, 0.1003, 0.0999, 0.0979, 0.0983, 0.0985, 0.0983],
#         [0.1022, 0.0985, 0.0998, 0.0995, 0.0976, 0.0979, 0.0981, 0.0980],
#         [0.1015, 0.0980, 0.0990, 0.0990, 0.0972, 0.0974, 0.0976, 0.0976]])
# 1.weight grad: tensor([[-5.5327e-03,  8.6230e-04, -2.3319e-03, -7.7246e-04,  2.1549e-03,
#           1.2390e-03,  1.1992e-03,  1.7843e-03],
#         [-2.6283e-03,  1.9482e-03,  8.2204e-04,  5.4707e-04,  3.0584e-03,
#           2.9016e-03,  2.4536e-03,  2.4111e-03],
#         [-6.0152e-03,  5.8892e-04, -2.9725e-03, -1.0469e-03,  1.8819e-03,
#           8.2305e-04,  8.7701e-04,  1.5856e-03],
#         [-2.9846e-03,  1.8335e-03,  4.5832e-04,  3.9619e-04,  2.9721e-03,
#           2.7255e-03,  2.3224e-03,  2.3531e-03],
#         [-2.3497e-03,  2.0372e-03,  1.1055e-03,  6.6461e-04,  3.1249e-03,
#           3.0383e-03,  2.5552e-03,  2.4558e-03],
#         [-3.5997e-03,  1.5307e-03, -3.0096e-04,  7.3468e-05,  2.6844e-03,
#           2.2639e-03,  1.9676e-03,  2.1463e-03],
#         [-2.9158e-03,  1.8192e-03,  4.8277e-04,  4.0363e-04,  2.9404e-03,
#           2.7046e-03,  2.3030e-03,  2.3272e-03],
#         [-1.8803e-03,  2.2434e-03,  1.6536e-03,  8.9607e-04,  3.3115e-03,
#           3.3531e-03,  2.7955e-03,  2.5883e-03]])
# 1.bias data: tensor([-0.0091,  0.0249, -0.0164,  0.0210,  0.0278,  0.0125,  0.0211,  0.0339])
# 1.bias grad: tensor([ 0.0134, -0.0350,  0.0239, -0.0296, -0.0393, -0.0174, -0.0296, -0.0479])
# 3.weight data: tensor([[-0.1398,  0.1627, -0.2039,  0.1283,  0.1894,  0.0534,  0.1295,  0.2429]])
# 3.weight grad: tensor([[ 0.0058,  0.0003,  0.0070,  0.0010, -0.0001,  0.0023,  0.0009, -0.0011]])
# 3.bias data: tensor([-0.0921])
# 3.bias grad: tensor([-0.1610])
# epoch 4：
# 0.weight data: tensor([[-0.3811, -0.0793,  0.2477, -0.4919],
#         [-0.4294, -0.0051,  0.0947, -0.1152],
#         [-0.2401, -0.0871, -0.3302,  0.1950],
#         [-0.4377, -0.4623, -0.1647,  0.1332],
#         [-0.1423,  0.0505, -0.1142, -0.2791],
#         [-0.4233, -0.2119,  0.4646,  0.3153],
#         [ 0.0065, -0.1471,  0.0376,  0.1088],
#         [-0.1480, -0.3733, -0.2106, -0.3045]])
# 0.weight grad: tensor([[-3.4056e-05, -2.0837e-05,  1.6497e-05,  1.4698e-06],
#         [-3.2659e-05, -1.9982e-05,  1.5820e-05,  1.4095e-06],
#         [-3.3172e-05, -2.0297e-05,  1.6069e-05,  1.4317e-06],
#         [-3.3053e-05, -2.0224e-05,  1.6011e-05,  1.4265e-06],
#         [-3.2342e-05, -1.9789e-05,  1.5667e-05,  1.3958e-06],
#         [-3.2475e-05, -1.9870e-05,  1.5731e-05,  1.4015e-06],
#         [-3.2538e-05, -1.9909e-05,  1.5762e-05,  1.4043e-06],
#         [-3.2485e-05, -1.9876e-05,  1.5736e-05,  1.4020e-06]])
# 0.bias data: tensor([ 0.4705, -0.1484,  0.0989,  0.0227, -0.2856, -0.2180, -0.1968, -0.2288])
# 0.bias grad: tensor([-0.0056, -0.0053, -0.0054, -0.0054, -0.0053, -0.0053, -0.0053, -0.0053])
# 1.weight data: tensor([[0.1043, 0.0995, 0.1017, 0.1008, 0.0985, 0.0991, 0.0992, 0.0988],
#         [0.1022, 0.0982, 0.0995, 0.0994, 0.0972, 0.0975, 0.0978, 0.0977],
#         [0.1047, 0.0998, 0.1022, 0.1011, 0.0988, 0.0995, 0.0995, 0.0991],
#         [0.1025, 0.0983, 0.0997, 0.0995, 0.0974, 0.0977, 0.0980, 0.0978],
#         [0.1020, 0.0981, 0.0993, 0.0992, 0.0971, 0.0974, 0.0977, 0.0976],
#         [0.1030, 0.0987, 0.1003, 0.0999, 0.0977, 0.0981, 0.0983, 0.0981],
#         [0.1024, 0.0983, 0.0997, 0.0995, 0.0974, 0.0977, 0.0980, 0.0979],
#         [0.1017, 0.0978, 0.0989, 0.0990, 0.0969, 0.0971, 0.0974, 0.0974]])
# 1.weight grad: tensor([[-4.2504e-03,  7.2100e-04, -1.8165e-03, -5.3896e-04,  1.7173e-03,
#           9.8155e-04,  9.7026e-04,  1.4473e-03],
#         [-1.9992e-03,  1.4085e-03,  6.5420e-04,  3.4846e-04,  2.2487e-03,
#           2.1678e-03,  1.8037e-03,  1.7392e-03],
#         [-4.6133e-03,  5.3831e-04, -2.3161e-03, -7.2245e-04,  1.5348e-03,
#           6.7566e-04,  7.4536e-04,  1.3291e-03],
#         [-2.2776e-03,  1.3378e-03,  3.6883e-04,  2.4677e-04,  2.2023e-03,
#           2.0440e-03,  1.7187e-03,  1.7173e-03],
#         [-1.7814e-03,  1.4633e-03,  8.7661e-04,  4.2768e-04,  2.2843e-03,
#           2.2638e-03,  1.8695e-03,  1.7558e-03],
#         [-2.7456e-03,  1.1386e-03, -2.2423e-04,  3.0583e-05,  2.0160e-03,
#           1.7075e-03,  1.4745e-03,  1.6009e-03],
#         [-2.2194e-03,  1.3246e-03,  3.8894e-04,  2.5224e-04,  2.1743e-03,
#           2.0252e-03,  1.7012e-03,  1.6942e-03],
#         [-1.4213e-03,  1.5970e-03,  1.3053e-03,  5.8298e-04,  2.4012e-03,
#           2.4914e-03,  2.0327e-03,  1.8260e-03]])
# 1.bias data: tensor([-0.0102,  0.0278, -0.0184,  0.0235,  0.0312,  0.0140,  0.0236,  0.0379])
# 1.bias grad: tensor([ 0.0103, -0.0268,  0.0185, -0.0227, -0.0301, -0.0133, -0.0227, -0.0367])
# 3.weight data: tensor([[-0.1403,  0.1627, -0.2045,  0.1283,  0.1895,  0.0533,  0.1295,  0.2430]])
# 3.weight grad: tensor([[ 0.0043, -0.0004,  0.0054,  0.0002, -0.0008,  0.0013,  0.0002, -0.0016]])
# 3.bias data: tensor([-0.0784])
# 3.bias grad: tensor([-0.1235])
# epoch 5：
# 0.weight data: tensor([[-0.3811, -0.0793,  0.2477, -0.4919],
#         [-0.4294, -0.0051,  0.0947, -0.1152],
#         [-0.2401, -0.0871, -0.3302,  0.1950],
#         [-0.4377, -0.4623, -0.1647,  0.1332],
#         [-0.1423,  0.0505, -0.1142, -0.2791],
#         [-0.4233, -0.2119,  0.4646,  0.3153],
#         [ 0.0065, -0.1471,  0.0376,  0.1088],
#         [-0.1480, -0.3733, -0.2106, -0.3045]])
# 0.weight grad: tensor([[-2.6644e-05, -1.6457e-05,  1.2265e-05,  4.1977e-07],
#         [-2.5467e-05, -1.5730e-05,  1.1723e-05,  4.0123e-07],
#         [-2.5897e-05, -1.5996e-05,  1.1921e-05,  4.0799e-07],
#         [-2.5800e-05, -1.5936e-05,  1.1877e-05,  4.0647e-07],
#         [-2.5200e-05, -1.5565e-05,  1.1600e-05,  3.9702e-07],
#         [-2.5310e-05, -1.5633e-05,  1.1651e-05,  3.9875e-07],
#         [-2.5365e-05, -1.5667e-05,  1.1676e-05,  3.9962e-07],
#         [-2.5321e-05, -1.5640e-05,  1.1656e-05,  3.9893e-07]])
# 0.bias data: tensor([ 0.4709, -0.1479,  0.0993,  0.0231, -0.2851, -0.2176, -0.1963, -0.2283])
# 0.bias grad: tensor([-0.0043, -0.0041, -0.0042, -0.0041, -0.0040, -0.0041, -0.0041, -0.0041])
# 1.weight data: tensor([[0.1047, 0.0995, 0.1019, 0.1008, 0.0983, 0.0990, 0.0991, 0.0987],
#         [0.1024, 0.0981, 0.0994, 0.0993, 0.0971, 0.0974, 0.0977, 0.0976],
#         [0.1051, 0.0998, 0.1024, 0.1012, 0.0987, 0.0994, 0.0995, 0.0990],
#         [0.1027, 0.0982, 0.0997, 0.0995, 0.0972, 0.0976, 0.0978, 0.0977],
#         [0.1022, 0.0980, 0.0992, 0.0992, 0.0970, 0.0972, 0.0975, 0.0975],
#         [0.1032, 0.0986, 0.1003, 0.0999, 0.0976, 0.0980, 0.0982, 0.0980],
#         [0.1026, 0.0982, 0.0997, 0.0995, 0.0972, 0.0976, 0.0978, 0.0977],
#         [0.1018, 0.0977, 0.0988, 0.0989, 0.0967, 0.0969, 0.0973, 0.0973]])
# 1.weight grad: tensor([[-3.2703e-03,  5.8917e-04, -1.4122e-03, -3.8266e-04,  1.3578e-03,
#           7.7262e-04,  7.7523e-04,  1.1587e-03],
#         [-1.5267e-03,  1.0330e-03,  5.1682e-04,  2.2669e-04,  1.6723e-03,
#           1.6328e-03,  1.3410e-03,  1.2732e-03],
#         [-3.5449e-03,  4.6447e-04, -1.8010e-03, -5.0793e-04,  1.2331e-03,
#           5.4517e-04,  6.1532e-04,  1.0877e-03],
#         [-1.7437e-03,  9.8869e-04,  2.9376e-04,  1.5672e-04,  1.6481e-03,
#           1.5441e-03,  1.2848e-03,  1.2695e-03],
#         [-1.3570e-03,  1.0672e-03,  6.9068e-04,  2.8121e-04,  1.6906e-03,
#           1.7015e-03,  1.3845e-03,  1.2756e-03],
#         [-2.1011e-03,  8.5477e-04, -1.6829e-04,  8.8469e-06,  1.5248e-03,
#           1.2957e-03,  1.1133e-03,  1.2045e-03],
#         [-1.6958e-03,  9.7722e-04,  3.1001e-04,  1.6079e-04,  1.6244e-03,
#           1.5281e-03,  1.2697e-03,  1.2498e-03],
#         [-1.0802e-03,  1.1557e-03,  1.0250e-03,  3.8761e-04,  1.7653e-03,
#           1.8684e-03,  1.4977e-03,  1.3113e-03]])
# 1.bias data: tensor([-0.0111,  0.0301, -0.0200,  0.0255,  0.0337,  0.0151,  0.0256,  0.0411])
# 1.bias grad: tensor([ 0.0080, -0.0206,  0.0142, -0.0174, -0.0231, -0.0102, -0.0174, -0.0282])
# 3.weight data: tensor([[-0.1406,  0.1628, -0.2049,  0.1283,  0.1896,  0.0532,  0.1295,  0.2432]])
# 3.weight grad: tensor([[ 0.0033, -0.0006,  0.0041, -0.0002, -0.0010,  0.0008, -0.0002, -0.0017]])
# 3.bias data: tensor([-0.0679])
# 3.bias grad: tensor([-0.0948])
# epoch 6：
# 0.weight data: tensor([[-0.3811, -0.0793,  0.2477, -0.4919],
#         [-0.4294, -0.0051,  0.0947, -0.1152],
#         [-0.2401, -0.0871, -0.3302,  0.1950],
#         [-0.4377, -0.4623, -0.1647,  0.1332],
#         [-0.1423,  0.0505, -0.1142, -0.2791],
#         [-0.4233, -0.2119,  0.4646,  0.3153],
#         [ 0.0065, -0.1471,  0.0376,  0.1088],
#         [-0.1480, -0.3733, -0.2106, -0.3045]])
# 0.weight grad: tensor([[-2.0999e-05, -1.3122e-05,  9.0409e-06, -3.8127e-07],
#         [-2.0022e-05, -1.2511e-05,  8.6200e-06, -3.6352e-07],
#         [-2.0376e-05, -1.2732e-05,  8.7726e-06, -3.6996e-07],
#         [-2.0299e-05, -1.2684e-05,  8.7392e-06, -3.6855e-07],
#         [-1.9799e-05, -1.2372e-05,  8.5243e-06, -3.5949e-07],
#         [-1.9890e-05, -1.2429e-05,  8.5633e-06, -3.6113e-07],
#         [-1.9936e-05, -1.2458e-05,  8.5833e-06, -3.6197e-07],
#         [-1.9901e-05, -1.2435e-05,  8.5679e-06, -3.6132e-07]])
# 0.bias data: tensor([ 0.4713, -0.1476,  0.0997,  0.0235, -0.2848, -0.2172, -0.1960, -0.2280])
# 0.bias grad: tensor([-0.0033, -0.0031, -0.0032, -0.0032, -0.0031, -0.0031, -0.0031, -0.0031])
# 1.weight data: tensor([[0.1050, 0.0994, 0.1020, 0.1009, 0.0982, 0.0990, 0.0990, 0.0986],
#         [0.1025, 0.0980, 0.0994, 0.0993, 0.0969, 0.0972, 0.0975, 0.0975],
#         [0.1054, 0.0997, 0.1025, 0.1012, 0.0985, 0.0994, 0.0994, 0.0989],
#         [0.1028, 0.0982, 0.0997, 0.0995, 0.0971, 0.0974, 0.0977, 0.0976],
#         [0.1023, 0.0979, 0.0992, 0.0992, 0.0968, 0.0971, 0.0974, 0.0974],
#         [0.1034, 0.0985, 0.1003, 0.0999, 0.0974, 0.0979, 0.0981, 0.0979],
#         [0.1028, 0.0982, 0.0997, 0.0995, 0.0971, 0.0974, 0.0977, 0.0976],
#         [0.1019, 0.0976, 0.0987, 0.0989, 0.0966, 0.0968, 0.0971, 0.0972]])
# 1.weight grad: tensor([[-2.5206e-03,  4.7429e-04, -1.0971e-03, -2.7612e-04,  1.0679e-03,
#           6.0555e-04,  6.1420e-04,  9.1970e-04],
#         [-1.1698e-03,  7.6698e-04,  4.0653e-04,  1.5096e-04,  1.2556e-03,
#           1.2383e-03,  1.0067e-03,  9.4396e-04],
#         [-2.7296e-03,  3.8736e-04, -1.3994e-03, -3.6345e-04,  9.8099e-04,
#           4.3476e-04,  4.9854e-04,  8.7657e-04],
#         [-1.3387e-03,  7.3871e-04,  2.3252e-04,  1.0182e-04,  1.2437e-03,
#           1.1738e-03,  9.6858e-04,  9.4880e-04],
#         [-1.0377e-03,  7.8879e-04,  5.4217e-04,  1.8925e-04,  1.2645e-03,
#           1.2883e-03,  1.0360e-03,  9.3989e-04],
#         [-1.6126e-03,  6.4672e-04, -1.2707e-04, -1.4477e-06,  1.1603e-03,
#           9.8834e-04,  8.4593e-04,  9.1302e-04],
#         [-1.3000e-03,  7.2913e-04,  2.4550e-04,  1.0488e-04,  1.2241e-03,
#           1.1605e-03,  9.5611e-04,  9.3250e-04],
#         [-8.2454e-04,  8.4873e-04,  8.0249e-04,  2.6366e-04,  1.3133e-03,
#           1.4122e-03,  1.1161e-03,  9.5672e-04]])
# 1.bias data: tensor([-0.0118,  0.0318, -0.0212,  0.0269,  0.0357,  0.0160,  0.0270,  0.0434])
# 1.bias grad: tensor([ 0.0062, -0.0158,  0.0110, -0.0134, -0.0178, -0.0078, -0.0134, -0.0217])
# 3.weight data: tensor([[-0.1409,  0.1628, -0.2052,  0.1283,  0.1897,  0.0531,  0.1295,  0.2434]])
# 3.weight grad: tensor([[ 0.0025, -0.0007,  0.0032, -0.0003, -0.0010,  0.0005, -0.0004, -0.0016]])
# 3.bias data: tensor([-0.0599])
# 3.bias grad: tensor([-0.0730])
# epoch 7：
# 0.weight data: tensor([[-0.3811, -0.0793,  0.2477, -0.4919],
#         [-0.4294, -0.0051,  0.0947, -0.1152],
#         [-0.2401, -0.0871, -0.3302,  0.1950],
#         [-0.4377, -0.4623, -0.1647,  0.1332],
#         [-0.1423,  0.0505, -0.1142, -0.2791],
#         [-0.4233, -0.2119,  0.4646,  0.3153],
#         [ 0.0065, -0.1471,  0.0376,  0.1088],
#         [-0.1480, -0.3733, -0.2106, -0.3045]])
# 0.weight grad: tensor([[-1.6694e-05, -1.0578e-05,  6.5809e-06, -9.9298e-07],
#         [-1.5887e-05, -1.0066e-05,  6.2627e-06, -9.4496e-07],
#         [-1.6178e-05, -1.0251e-05,  6.3776e-06, -9.6229e-07],
#         [-1.6116e-05, -1.0211e-05,  6.3530e-06, -9.5858e-07],
#         [-1.5703e-05, -9.9499e-06,  6.1903e-06, -9.3403e-07],
#         [-1.5777e-05, -9.9970e-06,  6.2196e-06, -9.3845e-07],
#         [-1.5816e-05, -1.0022e-05,  6.2349e-06, -9.4076e-07],
#         [-1.5787e-05, -1.0003e-05,  6.2234e-06, -9.3904e-07]])
# 0.bias data: tensor([ 0.4716, -0.1473,  0.1000,  0.0237, -0.2845, -0.2170, -0.1957, -0.2277])
# 0.bias grad: tensor([-0.0025, -0.0024, -0.0025, -0.0024, -0.0024, -0.0024, -0.0024, -0.0024])
# 1.weight data: tensor([[0.1052, 0.0994, 0.1021, 0.1009, 0.0981, 0.0989, 0.0990, 0.0985],
#         [0.1026, 0.0979, 0.0994, 0.0993, 0.0968, 0.0971, 0.0975, 0.0974],
#         [0.1056, 0.0997, 0.1026, 0.1012, 0.0985, 0.0993, 0.0994, 0.0988],
#         [0.1029, 0.0981, 0.0997, 0.0995, 0.0970, 0.0973, 0.0976, 0.0975],
#         [0.1024, 0.0978, 0.0991, 0.0992, 0.0967, 0.0970, 0.0973, 0.0973],
#         [0.1035, 0.0985, 0.1003, 0.0999, 0.0973, 0.0978, 0.0980, 0.0978],
#         [0.1029, 0.0981, 0.0996, 0.0995, 0.0970, 0.0973, 0.0976, 0.0975],
#         [0.1020, 0.0976, 0.0986, 0.0989, 0.0965, 0.0967, 0.0971, 0.0971]])
# 1.weight grad: tensor([[-1.9471e-03,  3.7817e-04, -8.5268e-04, -2.0225e-04,  8.3748e-04,
#           4.7344e-04,  4.8407e-04,  7.2618e-04],
#         [-8.9922e-04,  5.7579e-04,  3.1918e-04,  1.0313e-04,  9.5094e-04,
#           9.4504e-04,  7.6213e-04,  7.0788e-04],
#         [-2.1071e-03,  3.1631e-04, -1.0879e-03, -2.6439e-04,  7.7558e-04,
#           3.4406e-04,  3.9907e-04,  6.9954e-04],
#         [-1.0306e-03,  5.5734e-04,  1.8348e-04,  6.7936e-05,  9.4562e-04,
#           8.9737e-04,  7.3576e-04,  7.1605e-04],
#         [-7.9639e-04,  5.9000e-04,  4.2496e-04,  1.3056e-04,  9.5478e-04,
#           9.8193e-04,  7.8245e-04,  7.0127e-04],
#         [-1.2415e-03,  4.9274e-04, -9.6437e-05, -5.6740e-06,  8.8786e-04,
#           7.5751e-04,  6.4647e-04,  6.9667e-04],
#         [-9.9969e-04,  5.4950e-04,  1.9378e-04,  7.0252e-05,  9.2973e-04,
#           8.8653e-04,  7.2561e-04,  7.0281e-04],
#         [-6.3173e-04,  6.3151e-04,  6.2770e-04,  1.8367e-04,  9.8732e-04,
#           1.0750e-03,  8.4019e-04,  7.0811e-04]])
# 1.bias data: tensor([-0.0123,  0.0332, -0.0221,  0.0280,  0.0371,  0.0166,  0.0281,  0.0452])
# 1.bias grad: tensor([ 0.0048, -0.0122,  0.0085, -0.0103, -0.0137, -0.0060, -0.0103, -0.0168])
# 3.weight data: tensor([[-0.1411,  0.1629, -0.2055,  0.1284,  0.1898,  0.0531,  0.1296,  0.2435]])
# 3.weight grad: tensor([[ 0.0019, -0.0007,  0.0025, -0.0004, -0.0009,  0.0003, -0.0004, -0.0014]])
# 3.bias data: tensor([-0.0539])
# 3.bias grad: tensor([-0.0563])
# epoch 8：
# 0.weight data: tensor([[-0.3811, -0.0793,  0.2477, -0.4919],
#         [-0.4294, -0.0051,  0.0947, -0.1152],
#         [-0.2401, -0.0871, -0.3302,  0.1950],
#         [-0.4377, -0.4623, -0.1647,  0.1332],
#         [-0.1423,  0.0505, -0.1142, -0.2791],
#         [-0.4233, -0.2119,  0.4646,  0.3153],
#         [ 0.0065, -0.1471,  0.0376,  0.1088],
#         [-0.1480, -0.3733, -0.2106, -0.3045]])
# 0.weight grad: tensor([[-1.3408e-05, -8.6365e-06,  4.7032e-06, -1.4602e-06],
#         [-1.2741e-05, -8.2071e-06,  4.4694e-06, -1.3876e-06],
#         [-1.2981e-05, -8.3615e-06,  4.5534e-06, -1.4137e-06],
#         [-1.2931e-05, -8.3290e-06,  4.5357e-06, -1.4082e-06],
#         [-1.2590e-05, -8.1093e-06,  4.4161e-06, -1.3711e-06],
#         [-1.2651e-05, -8.1486e-06,  4.4375e-06, -1.3777e-06],
#         [-1.2683e-05, -8.1694e-06,  4.4488e-06, -1.3813e-06],
#         [-1.2659e-05, -8.1542e-06,  4.4405e-06, -1.3787e-06]])
# 0.bias data: tensor([ 0.4718, -0.1471,  0.1002,  0.0239, -0.2843, -0.2168, -0.1955, -0.2275])
# 0.bias grad: tensor([-0.0020, -0.0019, -0.0019, -0.0019, -0.0018, -0.0019, -0.0019, -0.0019])
# 1.weight data: tensor([[0.1053, 0.0993, 0.1021, 0.1009, 0.0981, 0.0989, 0.0990, 0.0985],
#         [0.1027, 0.0979, 0.0993, 0.0993, 0.0968, 0.0971, 0.0974, 0.0973],
#         [0.1058, 0.0997, 0.1027, 0.1012, 0.0984, 0.0993, 0.0993, 0.0988],
#         [0.1030, 0.0981, 0.0997, 0.0995, 0.0969, 0.0973, 0.0976, 0.0975],
#         [0.1024, 0.0978, 0.0991, 0.0992, 0.0966, 0.0969, 0.0973, 0.0973],
#         [0.1036, 0.0984, 0.1003, 0.0999, 0.0973, 0.0977, 0.0980, 0.0978],
#         [0.1030, 0.0981, 0.0996, 0.0995, 0.0969, 0.0973, 0.0976, 0.0975],
#         [0.1020, 0.0975, 0.0986, 0.0989, 0.0964, 0.0966, 0.0970, 0.0970]])
# 1.weight grad: tensor([[-1.5085e-03,  2.9985e-04, -6.6383e-04, -1.5021e-04,  6.5616e-04,
#           3.6988e-04,  3.8047e-04,  5.7193e-04],
#         [-6.9361e-04,  4.3668e-04,  2.5067e-04,  7.2420e-05,  7.2598e-04,
#           7.2563e-04,  5.8162e-04,  5.3644e-04],
#         [-1.6317e-03,  2.5492e-04, -8.4715e-04, -1.9534e-04,  6.1118e-04,
#           2.7103e-04,  3.1707e-04,  5.5511e-04],
#         [-7.9605e-04,  4.2433e-04,  1.4472e-04,  4.6728e-05,  7.2409e-04,
#           6.8992e-04,  5.6293e-04,  5.4533e-04],
#         [-6.1344e-04,  4.4618e-04,  3.3325e-04,  9.2443e-05,  7.2722e-04,
#           7.5325e-04,  5.9601e-04,  5.2931e-04],
#         [-9.5905e-04,  3.7796e-04, -7.3537e-05, -6.7969e-06,  6.8314e-04,
#           5.8344e-04,  4.9684e-04,  5.3504e-04],
#         [-7.7146e-04,  4.1799e-04,  1.5285e-04,  4.8493e-05,  7.1134e-04,
#           6.8120e-04,  5.5476e-04,  5.3469e-04],
#         [-4.8579e-04,  4.7561e-04,  4.9139e-04,  1.3111e-04,  7.4952e-04,
#           8.2386e-04,  6.3841e-04,  5.3108e-04]])
# 1.bias data: tensor([-0.0127,  0.0342, -0.0228,  0.0289,  0.0383,  0.0171,  0.0290,  0.0466])
# 1.bias grad: tensor([ 0.0037, -0.0095,  0.0066, -0.0080, -0.0106, -0.0047, -0.0080, -0.0130])
# 3.weight data: tensor([[-0.1412,  0.1630, -0.2057,  0.1284,  0.1899,  0.0531,  0.1296,  0.2436]])
# 3.weight grad: tensor([[ 0.0015, -0.0006,  0.0019, -0.0004, -0.0008,  0.0002, -0.0004, -0.0011]])
# 3.bias data: tensor([-0.0492])
# 3.bias grad: tensor([-0.0436])
# epoch 9：
# 0.weight data: tensor([[-0.3811, -0.0793,  0.2477, -0.4919],
#         [-0.4294, -0.0051,  0.0947, -0.1152],
#         [-0.2401, -0.0871, -0.3302,  0.1950],
#         [-0.4377, -0.4623, -0.1647,  0.1332],
#         [-0.1423,  0.0505, -0.1142, -0.2791],
#         [-0.4233, -0.2119,  0.4646,  0.3153],
#         [ 0.0065, -0.1471,  0.0376,  0.1088],
#         [-0.1480, -0.3733, -0.2106, -0.3045]])
# 0.weight grad: tensor([[-1.0900e-05, -7.1546e-06,  3.2696e-06, -1.8171e-06],
#         [-1.0347e-05, -6.7915e-06,  3.1037e-06, -1.7249e-06],
#         [-1.0545e-05, -6.9217e-06,  3.1632e-06, -1.7580e-06],
#         [-1.0504e-05, -6.8946e-06,  3.1508e-06, -1.7511e-06],
#         [-1.0221e-05, -6.7087e-06,  3.0659e-06, -1.7039e-06],
#         [-1.0271e-05, -6.7418e-06,  3.0810e-06, -1.7123e-06],
#         [-1.0298e-05, -6.7596e-06,  3.0891e-06, -1.7168e-06],
#         [-1.0279e-05, -6.7468e-06,  3.0833e-06, -1.7136e-06]])
# 0.bias data: tensor([ 0.4719, -0.1470,  0.1003,  0.0241, -0.2842, -0.2166, -0.1954, -0.2274])
# 0.bias grad: tensor([-0.0015, -0.0014, -0.0015, -0.0015, -0.0014, -0.0014, -0.0014, -0.0014])
# 1.weight data: tensor([[0.1055, 0.0993, 0.1022, 0.1009, 0.0980, 0.0989, 0.0989, 0.0984],
#         [0.1028, 0.0979, 0.0993, 0.0993, 0.0967, 0.0970, 0.0974, 0.0973],
#         [0.1060, 0.0996, 0.1028, 0.1013, 0.0983, 0.0993, 0.0993, 0.0987],
#         [0.1031, 0.0980, 0.0996, 0.0995, 0.0968, 0.0972, 0.0975, 0.0974],
#         [0.1025, 0.0977, 0.0991, 0.0992, 0.0966, 0.0969, 0.0972, 0.0972],
#         [0.1037, 0.0984, 0.1003, 0.0999, 0.0972, 0.0977, 0.0979, 0.0977],
#         [0.1030, 0.0980, 0.0996, 0.0995, 0.0969, 0.0972, 0.0975, 0.0974],
#         [0.1021, 0.0975, 0.0985, 0.0989, 0.0963, 0.0965, 0.0969, 0.0970]])
# 1.weight grad: tensor([[-1.1733e-03,  2.3717e-04, -5.1835e-04, -1.1302e-04,  5.1458e-04,
#           2.8922e-04,  2.9888e-04,  4.5037e-04],
#         [-5.3717e-04,  3.3446e-04,  1.9730e-04,  5.2353e-05,  5.5868e-04,
#           5.6072e-04,  4.4739e-04,  4.1064e-04],
#         [-1.2687e-03,  2.0389e-04, -6.6168e-04, -1.4644e-04,  4.8124e-04,
#           2.1306e-04,  2.5092e-04,  4.3943e-04],
#         [-6.1727e-04,  3.2594e-04,  1.1436e-04,  3.3249e-05,  5.5847e-04,
#           5.3361e-04,  4.3382e-04,  4.1902e-04],
#         [-4.7448e-04,  3.4099e-04,  2.6195e-04,  6.7243e-05,  5.5866e-04,
#           5.8169e-04,  4.5782e-04,  4.0396e-04],
#         [-7.4396e-04,  2.9193e-04, -5.6335e-05, -6.4338e-06,  5.2875e-04,
#           4.5178e-04,  3.8412e-04,  4.1369e-04],
#         [-5.9778e-04,  3.2086e-04,  1.2079e-04,  3.4602e-05,  5.4829e-04,
#           5.2665e-04,  4.2729e-04,  4.1051e-04],
#         [-3.7507e-04,  3.6236e-04,  3.8566e-04,  9.5930e-05,  5.7437e-04,
#           6.3581e-04,  4.8951e-04,  4.0333e-04]])
# 1.bias data: tensor([-0.0130,  0.0349, -0.0233,  0.0295,  0.0391,  0.0175,  0.0296,  0.0477])
# 1.bias grad: tensor([ 0.0029, -0.0074,  0.0051, -0.0062, -0.0082, -0.0036, -0.0062, -0.0101])
# 3.weight data: tensor([[-0.1413,  0.1630, -0.2058,  0.1285,  0.1899,  0.0531,  0.1297,  0.2437]])
# 3.weight grad: tensor([[ 1.1342e-03, -4.9997e-04,  1.4871e-03, -3.1570e-04, -6.4341e-04,
#           9.4128e-05, -3.1933e-04, -9.3434e-04]])
# 3.bias data: tensor([-0.0457])
# 3.bias grad: tensor([-0.0338])
