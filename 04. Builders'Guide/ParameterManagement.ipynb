# %%
import torch
import torch.nn as nn

net = nn.Sequential(nn.Linear(4, 8), nn.ReLU(), nn.Linear(8, 1))

X = torch.rand(size=[2, 4])
print(net(X))
# Out:
# tensor([[0.2839],
#         [0.4507]], grad_fn=<AddmmBackward0>)

# %%
# 参数访问
print(net[2].state_dict())
print(type(net[2].bias))
print(net[2].bias)
print(net[2].bias.data)
# Out:
# OrderedDict([('weight', tensor([[ 0.2886,  0.0419,  0.1251,  0.2836,  0.2142, -0.0825,  0.0351, -0.3389]])), ('bias', tensor([0.0422]))])
# <class 'torch.nn.parameter.Parameter'>
# Parameter containing:
# tensor([0.0422], requires_grad=True)
# tensor([0.0422])

# %%
print(*[(name, param.shape) for name, param in net[2].named_parameters()])
print(*[(name, param.shape) for name, param in net.named_parameters()])
# Out:
# ('weight', torch.Size([1, 8])) ('bias', torch.Size([1]))
# ('0.weight', torch.Size([8, 4])) ('0.bias', torch.Size([8])) ('2.weight', torch.Size([1, 8])) ('2.bias', torch.Size([1]))

# %%
print(net.state_dict()['2.bias'].data)
# Out:
# tensor([0.0422])

# %%
# 从嵌套块收集参数
def block1():
    return nn.Sequential(nn.Linear(4, 8), nn.ReLU(), nn.Linear(8, 4), nn.ReLU())

def block2():
    net = nn.Sequential()
    for i in range(4):
#         net._modules[f'block {i}'] = block1()
        net.add_module(f'block {i}', block1())
    
    return net
        
net = nn.Sequential(block2(), nn.Linear(4, 1))
print(net)
# Out:
# Sequential(
#   (0): Sequential(
#     (block 0): Sequential(
#       (0): Linear(in_features=4, out_features=8, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=8, out_features=4, bias=True)
#       (3): ReLU()
#     )
#     (block 1): Sequential(
#       (0): Linear(in_features=4, out_features=8, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=8, out_features=4, bias=True)
#       (3): ReLU()
#     )
#     (block 2): Sequential(
#       (0): Linear(in_features=4, out_features=8, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=8, out_features=4, bias=True)
#       (3): ReLU()
#     )
#     (block 3): Sequential(
#       (0): Linear(in_features=4, out_features=8, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=8, out_features=4, bias=True)
#       (3): ReLU()
#     )
#   )
#   (1): Linear(in_features=4, out_features=1, bias=True)
# )

# %%
print(net[0][1][0].bias.data)
# Out:
# tensor([ 0.4291, -0.3281,  0.2791, -0.2385, -0.0843,  0.4811, -0.0657, -0.2932])

# %%
# 参数绑定
shared = nn.Linear(8, 8)
# nn.init.constant_(shared.weight, 0.1)
# nn.init.constant_(shared.bias, 0)
shared.weight.data[:] = 0.1
shared.bias.data[:] = 0

net = nn.Sequential(nn.Linear(4, 8),
                    shared,
                    shared,
                    nn.Linear(8, 1))

n_train = 100
true_w = torch.tensor([0.1 * i for i in range(1, 5)])
features = torch.normal(size=(n_train, 4), mean=0, std=0.01)
labels = torch.mm(features, true_w.view(-1, 1))

batch_size = 10
train_data = torch.utils.data.TensorDataset(features, labels)
train_iter = torch.utils.data.DataLoader(train_data, batch_size=batch_size)

loss = nn.MSELoss()
optimizer = torch.optim.SGD(net.parameters(), lr=0.01)

n_epochs = 10
for epoch in range(n_epochs):
    for X, y in train_iter:
        optimizer.zero_grad()
        y_hat = net(X)
        l = loss(y_hat, y.view(y_hat.shape))
        l.backward()
        optimizer.step()
    
    print(f'epoch {epoch}：')
    for name, param in net.named_parameters():
        print(name, 'data:', param.data)
        print(name, 'grad:', param.grad)
# Out:
# epoch 0：
# 0.weight data: tensor([[-0.2823,  0.0223, -0.3545, -0.4966],
#         [-0.4306, -0.3385, -0.0948,  0.2568],
#         [ 0.0421,  0.2541,  0.1574, -0.0056],
#         [ 0.3775, -0.2353,  0.1913,  0.4906],
#         [-0.4121, -0.4571,  0.1292,  0.3607],
#         [-0.4476, -0.2497, -0.1919, -0.1957],
#         [ 0.4516, -0.1589, -0.4960, -0.3435],
#         [-0.1545,  0.0650, -0.3726,  0.4620]])
# 0.weight grad: tensor([[ 3.0421e-05,  5.6648e-05, -1.7939e-06, -1.8932e-05],
#         [ 3.0447e-05,  5.6697e-05, -1.7955e-06, -1.8948e-05],
#         [ 3.0568e-05,  5.6923e-05, -1.8026e-06, -1.9024e-05],
#         [ 3.0427e-05,  5.6660e-05, -1.7943e-06, -1.8936e-05],
#         [ 3.0276e-05,  5.6379e-05, -1.7854e-06, -1.8842e-05],
#         [ 3.0459e-05,  5.6719e-05, -1.7962e-06, -1.8955e-05],
#         [ 3.0431e-05,  5.6668e-05, -1.7946e-06, -1.8939e-05],
#         [ 3.0533e-05,  5.6858e-05, -1.8006e-06, -1.9002e-05]])
# 0.bias data: tensor([ 0.0470, -0.0183, -0.3293,  0.0361,  0.4184, -0.0554,  0.0146, -0.2501])
# 0.bias grad: tensor([0.0100, 0.0100, 0.0100, 0.0100, 0.0099, 0.0100, 0.0100, 0.0100])
# 1.weight data: tensor([[0.1000, 0.1001, 0.1005, 0.1000, 0.0995, 0.1001, 0.1000, 0.1004],
#         [0.1001, 0.1002, 0.1006, 0.1001, 0.0996, 0.1002, 0.1001, 0.1004],
#         [0.1000, 0.1002, 0.1006, 0.1001, 0.0995, 0.1002, 0.1001, 0.1004],
#         [0.1001, 0.1002, 0.1007, 0.1002, 0.0996, 0.1002, 0.1001, 0.1004],
#         [0.1000, 0.1001, 0.1006, 0.1001, 0.0995, 0.1001, 0.1000, 0.1004],
#         [0.0999, 0.0999, 0.1004, 0.0999, 0.0993, 0.1000, 0.0999, 0.1003],
#         [0.0998, 0.0999, 0.1004, 0.0998, 0.0993, 0.1000, 0.0999, 0.1003],
#         [0.0997, 0.0998, 0.1002, 0.0997, 0.0992, 0.0999, 0.0998, 0.1002]])
# 1.weight grad: tensor([[-3.2385e-04, -1.3401e-03, -5.0738e-03, -7.7137e-04,  4.2054e-03,
#          -1.2334e-03, -2.6573e-04, -3.2857e-03],
#         [-1.0294e-03, -2.1663e-03, -5.8503e-03, -1.7051e-03,  3.4806e-03,
#          -1.6339e-03, -6.2478e-04, -3.4165e-03],
#         [-7.0004e-04, -1.7848e-03, -5.5084e-03, -1.2707e-03,  3.8388e-03,
#          -1.4515e-03, -4.5761e-04, -3.3695e-03],
#         [-1.6725e-03, -2.9178e-03, -6.5511e-03, -2.5556e-03,  2.8136e-03,
#          -1.9974e-03, -9.5186e-04, -3.5310e-03],
#         [-4.7959e-04, -1.5177e-03, -5.2220e-03, -9.7577e-04,  4.0231e-03,
#          -1.3166e-03, -3.4448e-04, -3.2987e-03],
#         [ 1.4935e-03,  7.8449e-04, -3.0903e-03,  1.6324e-03,  6.0879e-03,
#          -2.0550e-04,  6.5871e-04, -2.9601e-03],
#         [ 1.7302e-03,  1.0623e-03, -2.8269e-03,  1.9460e-03,  6.3283e-03,
#          -7.0476e-05,  7.7926e-04, -2.9143e-03],
#         [ 3.1118e-03,  2.6751e-03, -1.3303e-03,  3.7725e-03,  7.7702e-03,
#           7.0842e-04,  1.4818e-03, -2.6744e-03]])
# 1.bias data: tensor([-0.0064, -0.0102, -0.0085, -0.0138, -0.0072,  0.0036,  0.0048,  0.0124])
# 1.bias grad: tensor([ 0.0562,  0.0901,  0.0744,  0.1209,  0.0635, -0.0309, -0.0423, -0.1084])
# 3.weight data: tensor([[ 0.1140,  0.2022,  0.1614,  0.2825,  0.1331, -0.1129, -0.1425, -0.3149]])
# 3.weight grad: tensor([[-0.0077, -0.0091, -0.0085, -0.0103, -0.0080, -0.0043, -0.0038, -0.0012]])
# 3.bias data: tensor([0.2063])
# 3.bias grad: tensor([0.3839])
# epoch 1：
# 0.weight data: tensor([[-0.2823,  0.0223, -0.3545, -0.4966],
#         [-0.4306, -0.3385, -0.0948,  0.2568],
#         [ 0.0421,  0.2541,  0.1574, -0.0056],
#         [ 0.3775, -0.2353,  0.1913,  0.4906],
#         [-0.4121, -0.4571,  0.1292,  0.3607],
#         [-0.4476, -0.2497, -0.1919, -0.1957],
#         [ 0.4516, -0.1589, -0.4960, -0.3435],
#         [-0.1545,  0.0650, -0.3726,  0.4620]])
# 0.weight grad: tensor([[ 2.3261e-05,  4.3698e-05, -1.6100e-06, -1.5100e-05],
#         [ 2.3300e-05,  4.3771e-05, -1.6127e-06, -1.5125e-05],
#         [ 2.3473e-05,  4.4096e-05, -1.6247e-06, -1.5238e-05],
#         [ 2.3272e-05,  4.3719e-05, -1.6108e-06, -1.5107e-05],
#         [ 2.3054e-05,  4.3309e-05, -1.5957e-06, -1.4966e-05],
#         [ 2.3312e-05,  4.3795e-05, -1.6136e-06, -1.5134e-05],
#         [ 2.3273e-05,  4.3720e-05, -1.6109e-06, -1.5108e-05],
#         [ 2.3417e-05,  4.3991e-05, -1.6208e-06, -1.5201e-05]])
# 0.bias data: tensor([ 0.0461, -0.0192, -0.3302,  0.0352,  0.4175, -0.0562,  0.0138, -0.2510])
# 0.bias grad: tensor([0.0077, 0.0077, 0.0078, 0.0077, 0.0076, 0.0077, 0.0077, 0.0078])
# 1.weight data: tensor([[0.1000, 0.1002, 0.1010, 0.1001, 0.0991, 0.1002, 0.1000, 0.1007],
#         [0.1002, 0.1004, 0.1012, 0.1003, 0.0993, 0.1003, 0.1001, 0.1007],
#         [0.1001, 0.1003, 0.1011, 0.1002, 0.0992, 0.1003, 0.1001, 0.1007],
#         [0.1003, 0.1005, 0.1013, 0.1005, 0.0994, 0.1004, 0.1002, 0.1007],
#         [0.1001, 0.1003, 0.1010, 0.1002, 0.0992, 0.1002, 0.1001, 0.1007],
#         [0.0997, 0.0998, 0.1006, 0.0997, 0.0988, 0.1000, 0.0999, 0.1006],
#         [0.0997, 0.0998, 0.1006, 0.0996, 0.0987, 0.1000, 0.0999, 0.1006],
#         [0.0994, 0.0995, 0.1003, 0.0993, 0.0985, 0.0999, 0.0997, 0.1005]])
# 1.weight grad: tensor([[-0.0005, -0.0013, -0.0042, -0.0010,  0.0030, -0.0009, -0.0001, -0.0023],
#         [-0.0011, -0.0022, -0.0050, -0.0020,  0.0023, -0.0012, -0.0003, -0.0022],
#         [-0.0008, -0.0018, -0.0046, -0.0015,  0.0027, -0.0011, -0.0002, -0.0022],
#         [-0.0018, -0.0030, -0.0057, -0.0029,  0.0017, -0.0014, -0.0005, -0.0020],
#         [-0.0006, -0.0015, -0.0043, -0.0012,  0.0028, -0.0010, -0.0002, -0.0022],
#         [ 0.0013,  0.0009, -0.0022,  0.0016,  0.0049, -0.0002,  0.0004, -0.0026],
#         [ 0.0016,  0.0012, -0.0019,  0.0020,  0.0051, -0.0001,  0.0005, -0.0026],
#         [ 0.0029,  0.0029, -0.0004,  0.0039,  0.0066,  0.0004,  0.0009, -0.0029]])
# 1.bias data: tensor([-0.0113, -0.0181, -0.0150, -0.0243, -0.0128,  0.0062,  0.0085,  0.0218])
# 1.bias grad: tensor([ 0.0431,  0.0688,  0.0570,  0.0922,  0.0485, -0.0232, -0.0318, -0.0821])
# 3.weight data: tensor([[ 0.1148,  0.2032,  0.1623,  0.2836,  0.1340, -0.1125, -0.1422, -0.3149]])
# 3.weight grad: tensor([[-0.0082, -0.0101, -0.0092, -0.0118, -0.0086, -0.0033, -0.0026,  0.0011]])
# 3.bias data: tensor([0.1730])
# 3.bias grad: tensor([0.2911])
# epoch 2：
# 0.weight data: tensor([[-0.2823,  0.0223, -0.3545, -0.4966],
#         [-0.4306, -0.3385, -0.0948,  0.2568],
#         [ 0.0421,  0.2541,  0.1574, -0.0056],
#         [ 0.3775, -0.2353,  0.1913,  0.4906],
#         [-0.4121, -0.4571,  0.1292,  0.3607],
#         [-0.4476, -0.2497, -0.1919, -0.1957],
#         [ 0.4516, -0.1589, -0.4960, -0.3435],
#         [-0.1545,  0.0650, -0.3726,  0.4620]])
# 0.weight grad: tensor([[ 1.7634e-05,  3.3525e-05, -1.4692e-06, -1.2097e-05],
#         [ 1.7675e-05,  3.3604e-05, -1.4726e-06, -1.2126e-05],
#         [ 1.7854e-05,  3.3943e-05, -1.4875e-06, -1.2248e-05],
#         [ 1.7647e-05,  3.3551e-05, -1.4703e-06, -1.2106e-05],
#         [ 1.7421e-05,  3.3120e-05, -1.4514e-06, -1.1951e-05],
#         [ 1.7685e-05,  3.3622e-05, -1.4734e-06, -1.2132e-05],
#         [ 1.7644e-05,  3.3544e-05, -1.4700e-06, -1.2104e-05],
#         [ 1.7791e-05,  3.3823e-05, -1.4822e-06, -1.2205e-05]])
# 0.bias data: tensor([ 0.0454, -0.0199, -0.3309,  0.0345,  0.4169, -0.0569,  0.0131, -0.2517])
# 0.bias grad: tensor([0.0060, 0.0060, 0.0060, 0.0060, 0.0059, 0.0060, 0.0060, 0.0060])
# 1.weight data: tensor([[0.1001, 0.1004, 0.1014, 0.1002, 0.0989, 0.1003, 0.1001, 0.1008],
#         [0.1003, 0.1006, 0.1016, 0.1005, 0.0991, 0.1004, 0.1001, 0.1008],
#         [0.1002, 0.1005, 0.1015, 0.1004, 0.0990, 0.1004, 0.1001, 0.1008],
#         [0.1005, 0.1008, 0.1018, 0.1007, 0.0992, 0.1005, 0.1002, 0.1009],
#         [0.1001, 0.1004, 0.1014, 0.1003, 0.0989, 0.1003, 0.1001, 0.1008],
#         [0.0996, 0.0998, 0.1008, 0.0995, 0.0983, 0.1001, 0.0998, 0.1008],
#         [0.0995, 0.0997, 0.1008, 0.0994, 0.0983, 0.1000, 0.0998, 0.1008],
#         [0.0991, 0.0992, 0.1003, 0.0989, 0.0979, 0.0999, 0.0997, 0.1008]])
# 1.weight grad: tensor([[-4.6476e-04, -1.2072e-03, -3.3858e-03, -9.8755e-04,  2.2224e-03,
#          -6.6989e-04, -4.5439e-05, -1.5987e-03],
#         [-1.0812e-03, -1.9992e-03, -4.1123e-03, -1.9338e-03,  1.5857e-03,
#          -8.4784e-04, -1.6204e-04, -1.3910e-03],
#         [-7.9190e-04, -1.6343e-03, -3.8030e-03, -1.4928e-03,  1.9147e-03,
#          -7.7030e-04, -1.0684e-04, -1.5081e-03],
#         [-1.6436e-03, -2.7195e-03, -4.7645e-03, -2.7960e-03,  9.9485e-04,
#          -1.0082e-03, -2.6856e-04, -1.1950e-03],
#         [-6.0257e-04, -1.3766e-03, -3.5125e-03, -1.1956e-03,  2.0461e-03,
#          -7.0293e-04, -7.2038e-05, -1.5302e-03],
#         [ 1.1243e-03,  8.2900e-04, -1.5384e-03,  1.4492e-03,  3.8876e-03,
#          -2.1597e-04,  2.5549e-04, -2.1496e-03],
#         [ 1.3309e-03,  1.0955e-03, -1.2905e-03,  1.7668e-03,  4.0969e-03,
#          -1.5550e-04,  2.9452e-04, -2.2166e-03],
#         [ 2.5398e-03,  2.6407e-03,  9.7516e-05,  3.6188e-03,  5.3802e-03,
#           1.8654e-04,  5.2370e-04, -2.6464e-03]])
# 1.bias data: tensor([-0.0151, -0.0241, -0.0199, -0.0323, -0.0170,  0.0082,  0.0113,  0.0289])
# 1.bias grad: tensor([ 0.0329,  0.0525,  0.0435,  0.0702,  0.0371, -0.0173, -0.0239, -0.0620])
# 3.weight data: tensor([[ 0.1156,  0.2042,  0.1631,  0.2848,  0.1348, -0.1123, -0.1421, -0.3151]])
# 3.weight grad: tensor([[-0.0075, -0.0095, -0.0086, -0.0113, -0.0080, -0.0025, -0.0018,  0.0020]])
# 3.bias data: tensor([0.1477])
# 3.bias grad: tensor([0.2203])
# epoch 3：
# 0.weight data: tensor([[-0.2823,  0.0223, -0.3545, -0.4966],
#         [-0.4306, -0.3385, -0.0948,  0.2569],
#         [ 0.0421,  0.2541,  0.1574, -0.0056],
#         [ 0.3775, -0.2353,  0.1913,  0.4906],
#         [-0.4121, -0.4571,  0.1292,  0.3607],
#         [-0.4476, -0.2497, -0.1919, -0.1957],
#         [ 0.4516, -0.1589, -0.4960, -0.3435],
#         [-0.1545,  0.0650, -0.3726,  0.4620]])
# 0.weight grad: tensor([[ 1.3211e-05,  2.5531e-05, -1.3604e-06, -9.7408e-06],
#         [ 1.3249e-05,  2.5604e-05, -1.3643e-06, -9.7687e-06],
#         [ 1.3409e-05,  2.5915e-05, -1.3809e-06, -9.8872e-06],
#         [ 1.3224e-05,  2.5556e-05, -1.3618e-06, -9.7505e-06],
#         [ 1.3018e-05,  2.5158e-05, -1.3406e-06, -9.5987e-06],
#         [ 1.3255e-05,  2.5617e-05, -1.3650e-06, -9.7735e-06],
#         [ 1.3218e-05,  2.5544e-05, -1.3612e-06, -9.7459e-06],
#         [ 1.3349e-05,  2.5798e-05, -1.3747e-06, -9.8428e-06]])
# 0.bias data: tensor([ 0.0449, -0.0204, -0.3314,  0.0340,  0.4164, -0.0574,  0.0126, -0.2522])
# 0.bias grad: tensor([0.0046, 0.0046, 0.0046, 0.0046, 0.0045, 0.0046, 0.0046, 0.0046])
# 1.weight data: tensor([[0.1001, 0.1005, 0.1017, 0.1003, 0.0987, 0.1004, 0.1001, 0.1010],
#         [0.1004, 0.1008, 0.1020, 0.1007, 0.0989, 0.1005, 0.1001, 0.1010],
#         [0.1003, 0.1006, 0.1018, 0.1005, 0.0988, 0.1004, 0.1001, 0.1010],
#         [0.1006, 0.1011, 0.1022, 0.1010, 0.0992, 0.1006, 0.1002, 0.1009],
#         [0.1002, 0.1005, 0.1017, 0.1004, 0.0987, 0.1004, 0.1001, 0.1010],
#         [0.0995, 0.0997, 0.1010, 0.0994, 0.0980, 0.1001, 0.0998, 0.1010],
#         [0.0994, 0.0996, 0.1009, 0.0993, 0.0979, 0.1000, 0.0998, 0.1010],
#         [0.0989, 0.0990, 0.1003, 0.0986, 0.0974, 0.0998, 0.0996, 0.1011]])
# 1.weight grad: tensor([[-4.2204e-04, -1.0249e-03, -2.6861e-03, -8.8527e-04,  1.6373e-03,
#          -4.9873e-04, -8.1153e-06, -1.1413e-03],
#         [-9.4111e-04, -1.7034e-03, -3.3071e-03, -1.7032e-03,  1.1021e-03,
#          -6.2121e-04, -7.4583e-05, -9.1568e-04],
#         [-6.9721e-04, -1.3910e-03, -3.0447e-03, -1.3218e-03,  1.3816e-03,
#          -5.6904e-04, -4.2731e-05, -1.0396e-03],
#         [-1.4147e-03, -2.3204e-03, -3.8640e-03, -2.4484e-03,  6.0461e-04,
#          -7.3117e-04, -1.3543e-04, -7.0387e-04],
#         [-5.3839e-04, -1.1698e-03, -2.7921e-03, -1.0653e-03,  1.4859e-03,
#          -5.2011e-04, -2.3712e-05, -1.0706e-03],
#         [ 9.1614e-04,  7.1933e-04, -1.1085e-03,  1.2209e-03,  3.0392e-03,
#          -1.8724e-04,  1.6374e-04, -1.7373e-03],
#         [ 1.0901e-03,  9.4763e-04, -8.9626e-04,  1.4955e-03,  3.2147e-03,
#          -1.4544e-04,  1.8593e-04, -1.8104e-03],
#         [ 2.1083e-03,  2.2712e-03,  2.8800e-04,  3.0963e-03,  4.2966e-03,
#           8.8606e-05,  3.1702e-04, -2.2736e-03]])
# 1.bias data: tensor([-0.0179, -0.0287, -0.0237, -0.0385, -0.0202,  0.0097,  0.0133,  0.0343])
# 1.bias grad: tensor([ 0.0251,  0.0399,  0.0331,  0.0533,  0.0282, -0.0130, -0.0180, -0.0468])
# 3.weight data: tensor([[ 0.1163,  0.2050,  0.1639,  0.2858,  0.1355, -0.1121, -0.1419, -0.3153]])
# 3.weight grad: tensor([[-0.0065, -0.0082, -0.0074, -0.0099, -0.0069, -0.0019, -0.0013,  0.0022]])
# 3.bias data: tensor([0.1285])
# 3.bias grad: tensor([0.1664])
# epoch 4：
# 0.weight data: tensor([[-0.2823,  0.0223, -0.3545, -0.4966],
#         [-0.4306, -0.3385, -0.0948,  0.2569],
#         [ 0.0421,  0.2541,  0.1574, -0.0056],
#         [ 0.3775, -0.2353,  0.1913,  0.4906],
#         [-0.4121, -0.4571,  0.1292,  0.3607],
#         [-0.4476, -0.2497, -0.1919, -0.1957],
#         [ 0.4516, -0.1589, -0.4960, -0.3435],
#         [-0.1545,  0.0650, -0.3726,  0.4620]])
# 0.weight grad: tensor([[ 9.7491e-06,  1.9276e-05, -1.2764e-06, -7.8988e-06],
#         [ 9.7811e-06,  1.9339e-05, -1.2806e-06, -7.9248e-06],
#         [ 9.9152e-06,  1.9604e-05, -1.2981e-06, -8.0334e-06],
#         [ 9.7609e-06,  1.9299e-05, -1.2779e-06, -7.9084e-06],
#         [ 9.5884e-06,  1.8958e-05, -1.2554e-06, -7.7687e-06],
#         [ 9.7851e-06,  1.9347e-05, -1.2811e-06, -7.9280e-06],
#         [ 9.7537e-06,  1.9285e-05, -1.2770e-06, -7.9026e-06],
#         [ 9.8626e-06,  1.9500e-05, -1.2912e-06, -7.9908e-06]])
# 0.bias data: tensor([ 0.0445, -0.0208, -0.3319,  0.0336,  0.4160, -0.0578,  0.0122, -0.2526])
# 0.bias grad: tensor([0.0035, 0.0035, 0.0036, 0.0035, 0.0034, 0.0035, 0.0035, 0.0035])
# 1.weight data: tensor([[0.1002, 0.1006, 0.1019, 0.1004, 0.0985, 0.1004, 0.1001, 0.1011],
#         [0.1005, 0.1009, 0.1023, 0.1008, 0.0988, 0.1005, 0.1001, 0.1010],
#         [0.1003, 0.1008, 0.1021, 0.1006, 0.0987, 0.1005, 0.1001, 0.1011],
#         [0.1007, 0.1013, 0.1026, 0.1012, 0.0991, 0.1006, 0.1002, 0.1010],
#         [0.1002, 0.1006, 0.1020, 0.1005, 0.0986, 0.1004, 0.1001, 0.1011],
#         [0.0994, 0.0996, 0.1011, 0.0993, 0.0977, 0.1001, 0.0998, 0.1012],
#         [0.0993, 0.0995, 0.1009, 0.0992, 0.0976, 0.1001, 0.0998, 0.1012],
#         [0.0987, 0.0988, 0.1003, 0.0983, 0.0970, 0.0998, 0.0996, 0.1013]])
# 1.weight grad: tensor([[-3.5901e-04, -8.3812e-04, -2.1005e-03, -7.4811e-04,  1.2115e-03,
#          -3.7202e-04,  8.8891e-06, -8.2329e-04],
#         [-7.8092e-04, -1.3957e-03, -2.6105e-03, -1.4238e-03,  7.7740e-04,
#          -4.5770e-04, -2.8956e-05, -6.1423e-04],
#         [-5.8251e-04, -1.1391e-03, -2.3962e-03, -1.1087e-03,  1.0057e-03,
#          -4.2198e-04, -1.0530e-05, -7.2786e-04],
#         [-1.1659e-03, -1.9026e-03, -3.0674e-03, -2.0394e-03,  3.7325e-04,
#          -5.3437e-04, -6.3698e-05, -4.1838e-04],
#         [-4.5376e-04, -9.5707e-04, -2.1863e-03, -8.9686e-04,  1.0868e-03,
#          -3.8611e-04, -3.1793e-07, -7.5909e-04],
#         [ 7.2885e-04,  5.9507e-04, -8.0592e-04,  9.9184e-04,  2.3501e-03,
#          -1.5473e-04,  1.0697e-04, -1.3745e-03],
#         [ 8.7023e-04,  7.8267e-04, -6.3150e-04,  1.2186e-03,  2.4922e-03,
#          -1.2538e-04,  1.1956e-04, -1.4424e-03],
#         [ 1.6980e-03,  1.8702e-03,  3.3968e-04,  2.5411e-03,  3.3717e-03,
#           3.7462e-05,  1.9454e-04, -1.8702e-03]])
# 1.bias data: tensor([-0.0201, -0.0322, -0.0266, -0.0431, -0.0227,  0.0108,  0.0149,  0.0384])
# 1.bias grad: tensor([ 0.0190,  0.0302,  0.0251,  0.0404,  0.0214, -0.0097, -0.0135, -0.0352])
# 3.weight data: tensor([[ 0.1169,  0.2058,  0.1646,  0.2867,  0.1361, -0.1119, -0.1418, -0.3156]])
# 3.weight grad: tensor([[-0.0053, -0.0068, -0.0061, -0.0082, -0.0056, -0.0015, -0.0009,  0.0020]])
# 3.bias data: tensor([0.1140])
# 3.bias grad: tensor([0.1253])
# epoch 5：
# 0.weight data: tensor([[-0.2823,  0.0223, -0.3545, -0.4966],
#         [-0.4306, -0.3385, -0.0948,  0.2569],
#         [ 0.0421,  0.2541,  0.1574, -0.0056],
#         [ 0.3775, -0.2353,  0.1913,  0.4906],
#         [-0.4121, -0.4571,  0.1292,  0.3607],
#         [-0.4476, -0.2497, -0.1919, -0.1957],
#         [ 0.4516, -0.1589, -0.4960, -0.3435],
#         [-0.1545,  0.0650, -0.3726,  0.4620]])
# 0.weight grad: tensor([[ 7.0569e-06,  1.4411e-05, -1.2116e-06, -6.4675e-06],
#         [ 7.0824e-06,  1.4463e-05, -1.2160e-06, -6.4909e-06],
#         [ 7.1879e-06,  1.4679e-05, -1.2341e-06, -6.5876e-06],
#         [ 7.0667e-06,  1.4431e-05, -1.2133e-06, -6.4765e-06],
#         [ 6.9303e-06,  1.4153e-05, -1.1899e-06, -6.3515e-06],
#         [ 7.0846e-06,  1.4468e-05, -1.2163e-06, -6.4929e-06],
#         [ 7.0598e-06,  1.4417e-05, -1.2121e-06, -6.4701e-06],
#         [ 7.1450e-06,  1.4591e-05, -1.2267e-06, -6.5483e-06]])
# 0.bias data: tensor([ 0.0442, -0.0211, -0.3322,  0.0333,  0.4157, -0.0581,  0.0118, -0.2529])
# 0.bias grad: tensor([0.0027, 0.0027, 0.0027, 0.0027, 0.0026, 0.0027, 0.0027, 0.0027])
# 1.weight data: tensor([[0.1002, 0.1006, 0.1021, 0.1005, 0.0984, 0.1004, 0.1001, 0.1011],
#         [0.1005, 0.1011, 0.1025, 0.1010, 0.0988, 0.1006, 0.1001, 0.1011],
#         [0.1004, 0.1009, 0.1023, 0.1007, 0.0986, 0.1005, 0.1001, 0.1011],
#         [0.1008, 0.1014, 0.1028, 0.1014, 0.0991, 0.1007, 0.1002, 0.1010],
#         [0.1003, 0.1007, 0.1022, 0.1006, 0.0985, 0.1005, 0.1001, 0.1011],
#         [0.0993, 0.0996, 0.1011, 0.0992, 0.0975, 0.1001, 0.0998, 0.1013],
#         [0.0992, 0.0994, 0.1010, 0.0990, 0.0974, 0.1001, 0.0998, 0.1013],
#         [0.0986, 0.0986, 0.1003, 0.0981, 0.0967, 0.0998, 0.0996, 0.1015]])
# 1.weight grad: tensor([[-2.9315e-04, -6.6780e-04, -1.6234e-03, -6.0906e-04,  8.9845e-04,
#          -2.7741e-04,  1.5337e-05, -5.9823e-04],
#         [-6.2782e-04, -1.1133e-03, -2.0308e-03, -1.1507e-03,  5.5473e-04,
#          -3.3809e-04, -6.1421e-06, -4.1899e-04],
#         [-4.7034e-04, -9.0831e-04, -1.8603e-03, -8.9810e-04,  7.3649e-04,
#          -3.1328e-04,  4.5352e-06, -5.1594e-04],
#         [-9.3324e-04, -1.5183e-03, -2.3957e-03, -1.6443e-03,  2.3442e-04,
#          -3.9223e-04, -2.5933e-05, -2.5123e-04],
#         [-3.6841e-04, -7.6277e-04, -1.6912e-03, -7.2834e-04,  7.9860e-04,
#          -2.8684e-04,  9.8650e-06, -5.4372e-04],
#         [ 5.6984e-04,  4.7727e-04, -5.8959e-04,  7.8591e-04,  1.8007e-03,
#          -1.2392e-04,  7.1178e-05, -1.0705e-03],
#         [ 6.8197e-04,  6.2718e-04, -4.5015e-04,  9.6771e-04,  1.9131e-03,
#          -1.0307e-04,  7.8296e-05, -1.1288e-03],
#         [ 1.3387e-03,  1.4960e-03,  3.2501e-04,  2.0280e-03,  2.6106e-03,
#           1.1697e-05,  1.2110e-04, -1.4950e-03]])
# 1.bias data: tensor([-0.0218, -0.0348, -0.0288, -0.0467, -0.0246,  0.0117,  0.0161,  0.0415])
# 1.bias grad: tensor([ 0.0144,  0.0228,  0.0190,  0.0304,  0.0161, -0.0072, -0.0101, -0.0265])
# 3.weight data: tensor([[ 0.1173,  0.2064,  0.1651,  0.2875,  0.1366, -0.1118, -0.1417, -0.3158]])
# 3.weight grad: tensor([[-0.0043, -0.0055, -0.0049, -0.0066, -0.0045, -0.0011, -0.0007,  0.0017]])
# 3.bias data: tensor([0.1030])
# 3.bias grad: tensor([0.0941])
# epoch 6：
# 0.weight data: tensor([[-0.2823,  0.0223, -0.3545, -0.4966],
#         [-0.4306, -0.3385, -0.0948,  0.2569],
#         [ 0.0421,  0.2541,  0.1574, -0.0056],
#         [ 0.3775, -0.2353,  0.1913,  0.4906],
#         [-0.4121, -0.4571,  0.1292,  0.3607],
#         [-0.4476, -0.2497, -0.1919, -0.1957],
#         [ 0.4516, -0.1589, -0.4960, -0.3435],
#         [-0.1545,  0.0650, -0.3726,  0.4620]])
# 0.weight grad: tensor([[ 4.9759e-06,  1.0652e-05, -1.1618e-06, -5.3617e-06],
#         [ 4.9952e-06,  1.0693e-05, -1.1663e-06, -5.3825e-06],
#         [ 5.0741e-06,  1.0862e-05, -1.1847e-06, -5.4676e-06],
#         [ 4.9836e-06,  1.0668e-05, -1.1636e-06, -5.3700e-06],
#         [ 4.8811e-06,  1.0449e-05, -1.1397e-06, -5.2596e-06],
#         [ 4.9963e-06,  1.0696e-05, -1.1666e-06, -5.3837e-06],
#         [ 4.9776e-06,  1.0656e-05, -1.1622e-06, -5.3636e-06],
#         [ 5.0412e-06,  1.0792e-05, -1.1771e-06, -5.4321e-06]])
# 0.bias data: tensor([ 0.0439, -0.0214, -0.3324,  0.0331,  0.4154, -0.0584,  0.0116, -0.2531])
# 0.bias grad: tensor([0.0020, 0.0020, 0.0020, 0.0020, 0.0020, 0.0020, 0.0020, 0.0020])
# 1.weight data: tensor([[0.1002, 0.1007, 0.1023, 0.1005, 0.0983, 0.1005, 0.1000, 0.1012],
#         [0.1006, 0.1011, 0.1027, 0.1011, 0.0987, 0.1006, 0.1001, 0.1011],
#         [0.1004, 0.1009, 0.1025, 0.1008, 0.0985, 0.1005, 0.1001, 0.1012],
#         [0.1009, 0.1016, 0.1031, 0.1016, 0.0990, 0.1007, 0.1002, 0.1010],
#         [0.1003, 0.1008, 0.1023, 0.1006, 0.0984, 0.1005, 0.1001, 0.1012],
#         [0.0993, 0.0995, 0.1012, 0.0991, 0.0974, 0.1001, 0.0998, 0.1014],
#         [0.0992, 0.0994, 0.1010, 0.0990, 0.0972, 0.1001, 0.0998, 0.1014],
#         [0.0985, 0.0985, 0.1002, 0.0979, 0.0965, 0.0998, 0.0996, 0.1016]])
# 1.weight grad: tensor([[-2.3269e-04, -5.2194e-04, -1.2422e-03, -4.8325e-04,  6.6666e-04,
#          -2.0644e-04,  1.6559e-05, -4.3675e-04],
#         [-4.9340e-04, -8.7075e-04, -1.5613e-03, -9.0833e-04,  3.9932e-04,
#          -2.4977e-04,  4.4529e-06, -2.8990e-04],
#         [-3.7067e-04, -7.1028e-04, -1.4281e-03, -7.1007e-04,  5.4126e-04,
#          -2.3235e-04,  1.0638e-05, -3.6912e-04],
#         [-7.3134e-04, -1.1878e-03, -1.8468e-03, -1.2957e-03,  1.5000e-04,
#          -2.8834e-04, -6.7567e-06, -1.5253e-04],
#         [-2.9138e-04, -5.9626e-04, -1.2949e-03, -5.7687e-04,  5.8836e-04,
#          -2.1284e-04,  1.3286e-05, -3.9233e-04],
#         [ 4.3962e-04,  3.7456e-04, -4.3300e-04,  6.1148e-04,  1.3689e-03,
#          -9.7055e-05,  4.8163e-05, -8.2346e-04],
#         [ 5.2696e-04,  4.9194e-04, -3.2375e-04,  7.5414e-04,  1.4562e-03,
#          -8.2123e-05,  5.2152e-05, -8.7126e-04],
#         [ 1.0386e-03,  1.1722e-03,  2.8281e-04,  1.5863e-03,  1.9994e-03,
#          -5.0630e-07,  7.6470e-05, -1.1711e-03]])
# 1.bias data: tensor([-0.0231, -0.0368, -0.0305, -0.0494, -0.0260,  0.0123,  0.0170,  0.0438])
# 1.bias grad: tensor([ 0.0108,  0.0171,  0.0143,  0.0229,  0.0121, -0.0054, -0.0075, -0.0198])
# 3.weight data: tensor([[ 0.1177,  0.2069,  0.1656,  0.2881,  0.1370, -0.1117, -0.1417, -0.3159]])
# 3.weight grad: tensor([[-0.0033, -0.0043, -0.0039, -0.0052, -0.0035, -0.0008, -0.0005,  0.0014]])
# 3.bias data: tensor([0.0947])
# 3.bias grad: tensor([0.0705])
# epoch 7：
# 0.weight data: tensor([[-0.2823,  0.0223, -0.3545, -0.4966],
#         [-0.4306, -0.3385, -0.0948,  0.2569],
#         [ 0.0421,  0.2541,  0.1574, -0.0056],
#         [ 0.3775, -0.2353,  0.1913,  0.4906],
#         [-0.4121, -0.4571,  0.1292,  0.3607],
#         [-0.4476, -0.2497, -0.1919, -0.1957],
#         [ 0.4516, -0.1589, -0.4960, -0.3435],
#         [-0.1545,  0.0650, -0.3726,  0.4620]])
# 0.weight grad: tensor([[ 3.3762e-06,  7.7622e-06, -1.1237e-06, -4.5120e-06],
#         [ 3.3900e-06,  7.7938e-06, -1.1283e-06, -4.5304e-06],
#         [ 3.4459e-06,  7.9223e-06, -1.1469e-06, -4.6051e-06],
#         [ 3.3818e-06,  7.7750e-06, -1.1255e-06, -4.5195e-06],
#         [ 3.3091e-06,  7.6078e-06, -1.1013e-06, -4.4223e-06],
#         [ 3.3905e-06,  7.7949e-06, -1.1284e-06, -4.5310e-06],
#         [ 3.3772e-06,  7.7644e-06, -1.1240e-06, -4.5133e-06],
#         [ 3.4221e-06,  7.8677e-06, -1.1390e-06, -4.5734e-06]])
# 0.bias data: tensor([ 0.0438, -0.0215, -0.3326,  0.0329,  0.4152, -0.0586,  0.0114, -0.2533])
# 0.bias grad: tensor([0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015])
# 1.weight data: tensor([[0.1003, 0.1007, 0.1024, 0.1006, 0.0983, 0.1005, 0.1000, 0.1012],
#         [0.1006, 0.1012, 0.1028, 0.1011, 0.0987, 0.1006, 0.1001, 0.1011],
#         [0.1005, 0.1010, 0.1026, 0.1009, 0.0985, 0.1005, 0.1001, 0.1012],
#         [0.1010, 0.1017, 0.1032, 0.1017, 0.0990, 0.1007, 0.1002, 0.1010],
#         [0.1003, 0.1008, 0.1024, 0.1007, 0.0984, 0.1005, 0.1001, 0.1012],
#         [0.0993, 0.0995, 0.1012, 0.0991, 0.0972, 0.1001, 0.0998, 0.1015],
#         [0.0991, 0.0993, 0.1011, 0.0989, 0.0971, 0.1001, 0.0998, 0.1015],
#         [0.0984, 0.0984, 0.1002, 0.0978, 0.0963, 0.0998, 0.0996, 0.1017]])
# 1.weight grad: tensor([[-1.8080e-04, -4.0177e-04, -9.4218e-04, -3.7617e-04,  4.9423e-04,
#          -1.5306e-04,  1.5403e-05, -3.1960e-04],
#         [-3.8099e-04, -6.7060e-04, -1.1881e-03, -7.0433e-04,  2.8920e-04,
#          -1.8415e-04,  8.6799e-06, -2.0284e-04],
#         [-2.8671e-04, -5.4695e-04, -1.0857e-03, -5.5126e-04,  3.9839e-04,
#          -1.7183e-04,  1.2246e-05, -2.6573e-04],
#         [-5.6371e-04, -9.1498e-04, -1.4082e-03, -1.0034e-03,  9.7876e-05,
#          -2.1176e-04,  2.4109e-06, -9.3659e-05],
#         [-2.2591e-04, -4.5902e-04, -9.8254e-04, -4.4845e-04,  4.3381e-04,
#          -1.5745e-04,  1.3439e-05, -2.8440e-04],
#         [ 3.3548e-04,  2.8915e-04, -3.1856e-04,  4.6894e-04,  1.0330e-03,
#          -7.4720e-05,  3.3060e-05, -6.2699e-04],
#         [ 4.0254e-04,  3.7962e-04, -2.3431e-04,  5.7907e-04,  1.1000e-03,
#          -6.3981e-05,  3.5257e-05, -6.6501e-04],
#         [ 7.9546e-04,  9.0385e-04,  2.3300e-04,  1.2215e-03,  1.5170e-03,
#          -5.6284e-06,  4.8914e-05, -9.0328e-04]])
# 1.bias data: tensor([-0.0240, -0.0384, -0.0318, -0.0514, -0.0271,  0.0128,  0.0176,  0.0456])
# 1.bias grad: tensor([ 0.0081,  0.0128,  0.0107,  0.0171,  0.0091, -0.0040, -0.0056, -0.0148])
# 3.weight data: tensor([[ 0.1180,  0.2073,  0.1659,  0.2885,  0.1373, -0.1116, -0.1416, -0.3161]])
# 3.weight grad: tensor([[-0.0026, -0.0033, -0.0030, -0.0040, -0.0027, -0.0006, -0.0004,  0.0011]])
# 3.bias data: tensor([0.0884])
# 3.bias grad: tensor([0.0526])
# epoch 8：
# 0.weight data: tensor([[-0.2823,  0.0223, -0.3545, -0.4966],
#         [-0.4306, -0.3385, -0.0948,  0.2569],
#         [ 0.0421,  0.2541,  0.1574, -0.0056],
#         [ 0.3775, -0.2353,  0.1913,  0.4906],
#         [-0.4121, -0.4571,  0.1292,  0.3607],
#         [-0.4476, -0.2497, -0.1919, -0.1957],
#         [ 0.4516, -0.1589, -0.4960, -0.3435],
#         [-0.1545,  0.0650, -0.3726,  0.4620]])
# 0.weight grad: tensor([[ 2.1521e-06,  5.5510e-06, -1.0946e-06, -3.8620e-06],
#         [ 2.1612e-06,  5.5744e-06, -1.0992e-06, -3.8783e-06],
#         [ 2.1980e-06,  5.6693e-06, -1.1179e-06, -3.9443e-06],
#         [ 2.1559e-06,  5.5607e-06, -1.0965e-06, -3.8687e-06],
#         [ 2.1080e-06,  5.4370e-06, -1.0721e-06, -3.7827e-06],
#         [ 2.1614e-06,  5.5749e-06, -1.0993e-06, -3.8786e-06],
#         [ 2.1527e-06,  5.5523e-06, -1.0949e-06, -3.8629e-06],
#         [ 2.1821e-06,  5.6284e-06, -1.1099e-06, -3.9159e-06]])
# 0.bias data: tensor([ 0.0436, -0.0217, -0.3327,  0.0327,  0.4151, -0.0587,  0.0113, -0.2535])
# 0.bias grad: tensor([0.0011, 0.0011, 0.0012, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011])
# 1.weight data: tensor([[0.1003, 0.1008, 0.1025, 0.1006, 0.0982, 0.1005, 0.1000, 0.1013],
#         [0.1007, 0.1013, 0.1029, 0.1012, 0.0986, 0.1006, 0.1001, 0.1011],
#         [0.1005, 0.1010, 0.1027, 0.1009, 0.0984, 0.1006, 0.1001, 0.1012],
#         [0.1010, 0.1018, 0.1033, 0.1018, 0.0990, 0.1007, 0.1002, 0.1010],
#         [0.1004, 0.1009, 0.1025, 0.1007, 0.0983, 0.1005, 0.1001, 0.1012],
#         [0.0992, 0.0995, 0.1013, 0.0990, 0.0971, 0.1001, 0.0998, 0.1015],
#         [0.0991, 0.0993, 0.1011, 0.0988, 0.0970, 0.1001, 0.0998, 0.1016],
#         [0.0983, 0.0983, 0.1002, 0.0976, 0.0962, 0.0998, 0.0996, 0.1018]])
# 1.weight grad: tensor([[-1.3802e-04, -3.0526e-04, -7.0859e-04, -2.8837e-04,  3.6554e-04,
#          -1.1286e-04,  1.3351e-05, -2.3388e-04],
#         [-2.8985e-04, -5.0971e-04, -8.9568e-04, -5.3826e-04,  2.1019e-04,
#          -1.3519e-04,  9.7280e-06, -1.4304e-04],
#         [-2.1832e-04, -4.1568e-04, -8.1789e-04, -4.2170e-04,  2.9311e-04,
#          -1.2645e-04,  1.1755e-05, -1.9192e-04],
#         [-4.2843e-04, -6.9558e-04, -1.0630e-03, -7.6596e-04,  6.5154e-05,
#          -1.5498e-04,  6.3150e-06, -5.8113e-05],
#         [-1.7226e-04, -3.4879e-04, -7.3915e-04, -3.4341e-04,  3.1954e-04,
#          -1.1590e-04,  1.2174e-05, -2.0655e-04],
#         [ 2.5355e-04,  2.2021e-04, -2.3432e-04,  3.5518e-04,  7.7396e-04,
#          -5.6692e-05,  2.2949e-05, -4.7300e-04],
#         [ 3.0441e-04,  2.8901e-04, -1.7021e-04,  4.3905e-04,  8.2465e-04,
#          -4.8966e-05,  2.4119e-05, -5.0259e-04],
#         [ 6.0244e-04,  6.8770e-04,  1.8511e-04,  9.2821e-04,  1.1408e-03,
#          -7.1859e-06,  3.1599e-05, -6.8791e-04]])
# 1.bias data: tensor([-0.0248, -0.0395, -0.0327, -0.0529, -0.0279,  0.0132,  0.0181,  0.0469])
# 1.bias grad: tensor([ 0.0060,  0.0096,  0.0080,  0.0127,  0.0068, -0.0030, -0.0042, -0.0110])
# 3.weight data: tensor([[ 0.1182,  0.2076,  0.1662,  0.2889,  0.1376, -0.1116, -0.1416, -0.3162]])
# 3.weight grad: tensor([[-0.0020, -0.0025, -0.0023, -0.0031, -0.0021, -0.0005, -0.0003,  0.0009]])
# 3.bias data: tensor([0.0837])
# 3.bias grad: tensor([0.0391])
# epoch 9：
# 0.weight data: tensor([[-0.2823,  0.0223, -0.3545, -0.4966],
#         [-0.4306, -0.3385, -0.0948,  0.2569],
#         [ 0.0421,  0.2541,  0.1574, -0.0056],
#         [ 0.3775, -0.2353,  0.1913,  0.4906],
#         [-0.4121, -0.4571,  0.1292,  0.3607],
#         [-0.4476, -0.2497, -0.1919, -0.1957],
#         [ 0.4516, -0.1589, -0.4960, -0.3435],
#         [-0.1545,  0.0650, -0.3726,  0.4620]])
# 0.weight grad: tensor([[ 1.2189e-06,  3.8652e-06, -1.0725e-06, -3.3665e-06],
#         [ 1.2242e-06,  3.8820e-06, -1.0771e-06, -3.3811e-06],
#         [ 1.2455e-06,  3.9496e-06, -1.0959e-06, -3.4400e-06],
#         [ 1.2211e-06,  3.8723e-06, -1.0744e-06, -3.3726e-06],
#         [ 1.1933e-06,  3.7841e-06, -1.0499e-06, -3.2958e-06],
#         [ 1.2242e-06,  3.8821e-06, -1.0772e-06, -3.3812e-06],
#         [ 1.2192e-06,  3.8661e-06, -1.0727e-06, -3.3672e-06],
#         [ 1.2362e-06,  3.9202e-06, -1.0877e-06, -3.4143e-06]])
# 0.bias data: tensor([ 0.0435, -0.0218, -0.3328,  0.0326,  0.4150, -0.0588,  0.0112, -0.2536])
# 0.bias grad: tensor([0.0008, 0.0008, 0.0009, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008])
# 1.weight data: tensor([[0.1003, 0.1008, 0.1025, 0.1006, 0.0982, 0.1005, 0.1000, 0.1013],
#         [0.1007, 0.1013, 0.1030, 0.1013, 0.0986, 0.1006, 0.1001, 0.1012],
#         [0.1005, 0.1011, 0.1028, 0.1010, 0.0984, 0.1006, 0.1001, 0.1012],
#         [0.1011, 0.1018, 0.1034, 0.1018, 0.0990, 0.1007, 0.1002, 0.1011],
#         [0.1004, 0.1009, 0.1026, 0.1008, 0.0983, 0.1005, 0.1001, 0.1012],
#         [0.0992, 0.0994, 0.1013, 0.0990, 0.0971, 0.1001, 0.0998, 0.1016],
#         [0.0991, 0.0993, 0.1011, 0.0988, 0.0969, 0.1001, 0.0998, 0.1016],
#         [0.0982, 0.0982, 0.1002, 0.0976, 0.0961, 0.0998, 0.0996, 0.1019]])
# 1.weight grad: tensor([[-1.0367e-04, -2.2910e-04, -5.2824e-04, -2.1811e-04,  2.6926e-04,
#          -8.2578e-05,  1.1132e-05, -1.7074e-04],
#         [-2.1747e-04, -3.8269e-04, -6.6881e-04, -4.0603e-04,  1.5290e-04,
#          -9.8560e-05,  9.3033e-06, -1.0128e-04],
#         [-1.6383e-04, -3.1206e-04, -6.1044e-04, -3.1838e-04,  2.1513e-04,
#          -9.2367e-05,  1.0417e-05, -1.3862e-04],
#         [-3.2135e-04, -5.2232e-04, -7.9451e-04, -5.7726e-04,  4.4227e-05,
#          -1.1270e-04,  7.5502e-06, -3.6340e-05],
#         [-1.2936e-04, -2.6180e-04, -5.5111e-04, -2.5949e-04,  2.3468e-04,
#          -8.4679e-05,  1.0436e-05, -1.4987e-04],
#         [ 1.8985e-04,  1.6565e-04, -1.7196e-04,  2.6584e-04,  5.7527e-04,
#          -4.2426e-05,  1.6050e-05, -3.5357e-04],
#         [ 2.2797e-04,  2.1734e-04, -1.2379e-04,  3.2891e-04,  6.1323e-04,
#          -3.6888e-05,  1.6628e-05, -3.7620e-04],
#         [ 4.5138e-04,  5.1684e-04,  1.4309e-04,  6.9676e-04,  8.5018e-04,
#          -7.0579e-06,  2.0509e-05, -5.1788e-04]])
# 1.bias data: tensor([-0.0253, -0.0404, -0.0335, -0.0541, -0.0285,  0.0134,  0.0185,  0.0479])
# 1.bias grad: tensor([ 0.0045,  0.0071,  0.0059,  0.0094,  0.0050, -0.0022, -0.0031, -0.0081])
# 3.weight data: tensor([[ 0.1184,  0.2078,  0.1664,  0.2892,  0.1378, -0.1116, -0.1416, -0.3162]])
# 3.weight grad: tensor([[-0.0015, -0.0019, -0.0017, -0.0023, -0.0016, -0.0003, -0.0002,  0.0007]])
# 3.bias data: tensor([0.0801])
# 3.bias grad: tensor([0.0289])
