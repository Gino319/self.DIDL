# %%
import torch
import torch.nn.functional as F
import sys
sys.path.append('..')
import myd2l

# %%
attention_weights = torch.eye(10).reshape((1, 1, 10, 10)).repeat((2, 2, 1, 1))
myd2l.show_heatmaps(attention_weights, xlabel='Keys', ylabel='Queries')

# %%
attention_weights = torch.rand((10, 10))
attention_weights = torch.stack([F.softmax(row, dim=0) for row in attention_weights]).reshape((1, 1, 10, 10))
myd2l.show_heatmaps(attention_weights, xlabel='Keys', ylabel='Queries')
